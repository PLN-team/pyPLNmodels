# %%
from gradient_descent import gradient_descent, minibatch_class
import utils

import matplotlib.pyplot as plt
from pandas import read_csv
import math
from timeit import default_timer as timer
from tqdm import tqdm 
import time 
import sys 
from __future__ import print_function
import psutil
import multiprocessing
import concurrent.futures
import threading



import numpy as np
import torch
from torch import nn
import scipy.linalg as SLA 
from scipy.linalg import toeplitz 
torch.set_default_dtype(torch.float64)

# %%
class Poisson_reg():
    '''
    Poisson regressor class. The purpose of this class is to initialize the PLN model.
    '''
    
    def __init__(self): 
        pass
    

    
    def fit(self,O,X,Y, Niter_max = 300, tol = 0.1, lr = 0.00008,  verbose = False): 
        '''
        We run a gradient ascent to maximize the log likelihood. We do this by hand : we compute the gradient ourselves. 
        The log likelihood considered is the one from a poisson regression model. It is the same as PLN without the latent layer Z. 
        We are only trying to have a good guess of beta before doing anything. 
        
        args : 
                '0' : offset, size (n,p)
                'X' : covariates, size (n,p)
                'Y' : samples , size (n,p)
                'Niter_max' :int  the number of iteration we are ready to do 
                'tol' : float. the tolerance criteria. We will stop if the norm of the gradient is less than 
                       or equal to this threshold
                'lr' : float. learning rate for the gradient ascent
                'verbose' : bool. if True, will print some stats on the 
                
        returns : None but update the parameter beta 
        '''
        
        #we initiate beta 
        beta = torch.rand(X.shape[1])
        i = 0
        grad_norm = 2*tol
        while i<Niter_max and  grad_norm > tol : # condition to keep going
            grad = grad_poiss_beta(O,X,Y,beta) # computes the gradient 
            grad_norm = torch.norm(grad) 
            beta += lr*grad_poiss_beta(O,X,Y,beta)# update beta 
            i+=1
            
            # some stats if we want some 
            if verbose == True : 
                if i % 10 == 0 : 
                    print('log likelihood  : ', compute_l(0,X,Y,beta))
                    print('Gradient norm : ', grad_norm)
        if i < Niter_max : 
            print('---------------------Tolerance reachedin {} iterations'.format(i))
        else : 
            print('---------------------Maximum number of iterations reached')
        print('----------------------Gradient norm : ', grad_norm)
        self.beta = beta # save beta 
        
        
    def fit_torch(self,O,X,Y, Niter_max = 300, tol = 0.1, lr = 0.0001, verbose = False): 
        '''
        Does exaclty the same as fit() but uses autodifferentiation of pytorch. 
        '''
        
        beta = torch.rand(X.shape[1], requires_grad = True)
        optimizer = torch.optim.Adam([beta], lr = lr)
        i = 0
        grad_norm = 2*tol
        while i<Niter_max and  grad_norm > tol :
            loss = -compute_l(O,X,Y,beta)
            loss.backward()
            optimizer.step()
            grad_norm = torch.norm(beta.grad)
            beta.grad.zero_()
            i+=1
            if verbose == True : 
                if i % 10 == 0 : 
                    print('log like : ', -loss)
                    print('grad_norm : ', grad_norm)
        if verbose :
            if i < Niter_max : 
                print('-------------------Tolerance reached in {} iterations'.format(i))
            else : 
                print('-------------------Maxium number of iterations reached')
        self.beta = beta 
    

def grad_poiss_beta(O,X,Y,beta): 
    return torch.sum(-torch.multiply(X,torch.exp(O+X@beta).reshape(-1,1))+torch.multiply(Y.reshape(-1,1),X),dim = 0)
    
def compute_l(O,X,Y,beta):
    return torch.sum(-torch.exp(O + X@beta)+torch.multiply(Y,O+X@beta))    
    
def sample(O,X,true_beta):
        parameter = np.exp(O + X@true_beta)
        return torch.poisson(parameter)

# %%
class sample_PLN(): 
    '''
    simple class to sample some variables with the PLN model. 
    The main method is the sample one, however we can also plot the data calling the plot_Y method. 
    The method conditional prior should not be used and have not been tested properly. 
    '''
    
    def __init__(self): 
        pass 

    def sample(self, Sigma, beta, O, covariates): 
        '''
        sample Poisson log Normal variables. 
        The number of samples is the the first size of O, the number of species
        considered is the second size of O
        The number of covariates considered is the first size of beta. 
        
        '''
        self.Sigma = Sigma # unknown parameter in practice
        self.beta = beta #unknown parameter in practice
        
        self.O = O 
        self.covariates = covariates
        
        self.Z = torch.stack([self.Sigma@np.random.randn(p) for _ in range(n)])
        
        self.n = self.O.shape[0]
        self.p = self.Sigma.shape[0]
        self.d = self.covariates.shape[1]
        
        parameter = torch.exp(self.O + self.covariates@self.beta + self.Z)
        self.Y = np.random.poisson(lam = parameter)
        return self.Y 
        #return parameter.numpy()
    def plot_Y(self): 
        '''
        plot all the Y_ij sampled before. There will be n*p values in total. The color represent the site number. 
        Note that we need to have called self.sample() before otherwise it won't print anything 
        '''
        color = np.array([[site]*self.p for site in range(self.n) ]).ravel()*10
        plt.scatter(np.arange(0,self.n*self.p),self.Y.ravel(), c = color, label = 'color = site number')
        plt.legend()
        plt.ylabel('count number')
        plt.show()

    def conditionalprior(self): 
        mu = self.O[0,0]
        functions = list()
        for i in range(self.n): 
            mu_i = self.covariates[i].dot(self.beta[0])
            functions.append(lambda z : -z**2/(2*self.Sigma[0,0]**2)-np.exp(mu_i+z)+float(self.Y[i])*(mu_i+z))
        return functions

# %%
class PLNmodel(): 
    '''
    PLN model. The goal of this class is to compute the parameter beta and Sigma of the PLN model. 
    We use here variationnal approximation since we can't compute the log likelihood of the 
    latent variables given the data. 
    '''
    
    
    def __init__(self, Sigma_init, beta_init, M_init, S_init): 
        
        '''
            Initialization : 
            'Y' : the data, size (n,p). n is the number of samples we have and p the number of species. 
                  THE TYPE IS INT
            'O': offset : additional offset. (not very important for comprehension). size (n,p)
            'covariates' : covariates, size (n,d)
            'Sigma_init' : initialization for Sigma. I plan to do a more advanced initialization. 
            'beta_init ' : Initialization for beta. I plan to do a more advanced initialization. 
            'M_init' : initialization for the variational parameter M
            'S_init ': initialization for the variational parameter S
        '''
        
        # model parameters
        self.Sigma = torch.clone(Sigma_init)
        self.Sigma.requires_grad_(True)
        self.beta = torch.clone(beta_init)
        self.beta.requires_grad_(True)
        
        #variational parameters
        self.M = torch.clone(M_init)
        self.M.requires_grad_(True)
        self.S = torch.clone(S_init) 
        self.S.requires_grad_(True)
        
        # some useful variables
        self.det_Sigma = torch.det(self.Sigma)
        self.inv_Sigma = torch.inverse(self.Sigma)
        
        # optimizer for the VE_step
        self.VE_step_optimizer = torch.optim.Adam([self.S,self.M], lr = 0.002)
        self.VE_step_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(self.VE_step_optimizer, patience = 3, factor = 0.9)
        
        #optimizer for the M_step
        self.M_step_optimizer = torch.optim.Adam([self.beta], lr = 0.01)
        self.M_step_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(self.M_step_optimizer, patience = 3, factor = 0.9)        
        
        #optimizer for a full gradient ascent
        self.full_optimizer = torch.optim.Adam([self.S,self.M,self.beta])
        
        # just to stocke the parameters
        self.params = {'M': self.M, 'S' : self.S, 'beta' : self.beta}
        
        # to stock the 
        self.MSE_Sigma_list = list()
        self.MSE_beta_list = list()
        self.ELBO_list = list()
        
        

        
    # we define here the gradients computed manually as a sanity check. We can check that they are equals 
    # to the gradients computed with the autodifferentiation of pytorch (diff = 1e-15)
    def grad_Sigma(self): 
        with torch.no_grad():
            self.inv_Sigma = torch.inverse(self.Sigma)
            grad = -self.n/2*(self.inv_Sigma)# + torch.diag(torch.diagonal(self.inv_Sigma))) on a enlevé car avec ça ca match avec pytorch. 
            grad += 1/2*(sum([self.inv_Sigma@(torch.outer(self.M[i,:],self.M[i,:])+ torch.diag(self.S[i,:]))@self.inv_Sigma  for i in range(self.n)]))
        return grad
    def grad_M(self): 
        with torch.no_grad():
            grad = -torch.mm(self.M,self.inv_Sigma)
            grad -= torch.exp(self.O + torch.mm(self.covariates,self.beta) + self.M + torch.pow(self.S,2)/2)
            grad += self.Y 
        return grad 
    def grad_S(self):
        with torch.no_grad():
            grad = -1/2*torch.mm(torch.ones((self.n,self.p)), torch.diag(torch.diag(self.inv_Sigma)))
            grad-= torch.mul(self.S,torch.exp(self.O + torch.mm(self.covariates,self.beta) + self.M + torch.pow(self.S,2)/2))
            grad += 1/2*torch.div(1,self.S)
        return grad 
    def grad_beta(self): 
        with torch.no_grad():
            grad = - torch.mm(self.covariates.T,torch.exp( self.O + self.M + torch.pow(self.S,2)/2 + torch.mm(self.covariates,self.beta)))
            grad += torch.mm(self.covariates.T,self.Y.double())
        return grad 
    
        
    def extract_data(self,data): 
        '''
        function to extract the data. This function is just here to have a code more compact. 
        
        args : 
              'data': list with 3 elements : Y, O and covariates in this order. 
        '''
        
        #known variables
        self.Y = data[0];self.O = data[1];self.covariates = data[2]
    
        self.n, self.p = self.Y.shape
    
        
    def compute_ELBO(self, Y, covariates,O,M,S,Sigma,beta): 
        ''' 
        computes the ELBO. We simply apply the formula given above. 
        '''
        batch_size = Y.shape[0]
        inv_Sigma = torch.inverse(Sigma)
        tmp = -batch_size/2*torch.log(torch.det(Sigma))
        
        # formula with the quadratic function and the trace 
        tmp -=1/2*( torch.sum(torch.mm(torch.mm(M,inv_Sigma),M.T).diagonal()))   # we can simplify here, takes too much time 
                                                                                           # we should remove the diagonal and do a more efficient multiplication
                                            
                        
        Gram_matrix = torch.mm(covariates,beta) # matrix with term (i,j): <x_i,beta_j>
        
        Exp_moment = torch.exp(M + torch.pow(S,2)/2)
        
        tmp += torch.sum(-torch.exp(O + Gram_matrix + M + torch.pow(S,2)/2) + torch.multiply(Y, O + Gram_matrix + M))
        
        for i in range(batch_size): 
            tmp += 1/2* torch.log(S[i,:].prod())
            tmp -= 1/2 * torch.trace(torch.multiply(inv_Sigma,S[i,:]))
            
        return tmp
    
    

    
    def torch_gradient_ascent(self,optimizer, scheduler, lr = None, tolerance = 2, N_epoch = 500, verbose = True, batch_size = None ): 
        '''
        gradient ascent function. We compute the gradients thanks to the autodifferentiation of pytorch. 
        
        args : 
                'optimizer' : torch.optim.optimizer. the optimizer for the parameters. 
                'scheduler' : torch.optim.lr_scheduler.  scheduler for the optimizer above. 
                
                # I will generalize this with dictionnaries 
                'params' : torch.Tensor . the params we want to optimize. they should have required_grad = True. 
                'params_names' : the names of the parameter 
                
                'lr' : float.  a learning rate if we want to set the optimizer learning rate to a certain lr. If None, 
                      it will take the actual learning_rate of the optimizer. 
                'tolerance': float. the threshold we set to stop the algorithm. It will stop if the norm of each gradient's parameter 
                             is lower than this threshold, or if we are not improving the loss more than tolerance. 
                'N_epoch': int. the Maximum number of epoch we are ready to do. 
                
                'Verbose' : bool. if True, will print some messages useful to interpret the gradient ascent. If False, nothing will be printed. 
                
                'batch_size' : int or None. If None, the batch size will be n, so it will be a classical vanilla algorithm. 
                              if int, we will split the data set in batch size and do a gradient step for each mini_batch. 
                              
        
        returns : the parameters optimized. 
        '''
        
        
        # we set the gradient to zero just to make sure the gradients are properly calculated
        optimizer.zero_grad()
        
        if lr is not None : # if we want to set a threshold, we set it. Ohterwise, we skip this condition and keep the actual learning_rate
            optimizer.param_groups[0]['lr'] = lr 
            
        if batch_size == None : 
            batch_size = self.Y.shape[0]
        
        stop_condition = False 
        i = 0
        old_epoch_loss = 1.
        while i < N_epoch and stop_condition == False: 
            epoch_loss = 0.
            #print('beginning of epoch')
            for Y_b, covariates_b, O_b, M_b, S_b in self.get_batch(batch_size): 
                epoch_loss += self.train_step(optimizer, Y_b, covariates_b, O_b, M_b, S_b, self.Sigma,self.beta)
            #print('epoch loss : ', epoch_loss)
            
            if verbose and i % 25 == 0 : 
                self.print_stats(epoch_loss, self.params, optimizer)
            i += 1
            scheduler.step(epoch_loss)
            
            # condition to see if we have reach the tolerance threshold
            if  abs(epoch_loss.item() - old_epoch_loss) < tolerance : #and i > 10 and max([torch.norm(param.grad) for param in params]) < tolerance  or
                #if max([torch.norm(param.grad) for param in params]) < tolerance  or abs(loss.item()- old_loss)>  tolerance :
                stop_condition = True 
            old_epoch_loss = epoch_loss
        self.current_ELBO = -epoch_loss.item()

        if verbose : # just print some stats if we want to 
            print('N_epoch : ', N_epoch)
            if stop_condition : 
                print('---------------------------------Tolerance {} reached in {} iterations'.format(tolerance, i))
            else : 
                print('---------------------------------Maximum number of iterations reached : ', N_epoch)
            self.print_stats(epoch_loss, self.params, optimizer)
    
    def train_step(self, optimizer, Y_,covariates_, O_,M_,S_,Sigma_, beta_): 
        optimizer.zero_grad()
        loss = -self.compute_ELBO(Y_, covariates_, O_, M_, S_,Sigma_,beta_)
        #print('loss : ', loss)
        loss.backward()
        if torch.isnan(loss).item() == True : 
            print('NAAAAAAAAN')
        else : self.last_param = self.params 
        optimizer.step()
        return loss 

   
    def get_batch(self,batch_size): 
        
        indices = np.arange(self.n)
        np.random.shuffle(indices)
        nb_full_batch, last_batch_size  = self.n//batch_size, self.n % batch_size  
        self.batch_size = batch_size
        for i in range(nb_full_batch): 
            yield   (self.Y[indices[i*batch_size: (i+1)*batch_size]], 
                    self.covariates[indices[i*batch_size: (i+1)*batch_size]],
                    self.O[indices[i*batch_size: (i+1)*batch_size]], 
                    self.M[indices[i*batch_size: (i+1)*batch_size]], 
                    self.S[indices[i*batch_size: (i+1)*batch_size]])
                  
        if last_batch_size != 0 : 
            self.batch_size = last_batch_size
            yield   (self.Y[indices[-last_batch_size:]], 
                    self.covariates[indices[-last_batch_size:]],
                    self.O[indices[-last_batch_size:]],
                    self.M[indices[-last_batch_size:]], 
                    self.S[indices[-last_batch_size:]])
            
    
    def full_grad_ascent(self, data, lr = None, tolerance = 2, N_iter = 500, verbose = True): 
        '''
        gradient ascent function. We compute the gradients thanks to the autodifferentiation of pytorch. 
        
        args : 
                
                # I will generalize this with dictionnaries 
                'params' : torch.Tensor . the params we want to optimize. they should have required_grad = True. 
                'params_names' : the names of the parameter 
                
                'lr' : float.  a learning rate if we want to set the optimizer learning rate to a certain lr. If None, 
                      it will take the actual learning_rate of the optimizer. 
                'tolerance': float. the threshold we set to stop the algorithm. It will stop if the norm of each gradient's parameter 
                             is lower than this threshold, or if we are not improving the loss more than tolerance. 
                'N_iter': int. the Maximum number of iterations we are ready to do. 
                
                'Verbose' : bool. if True, will print some messages useful to interpret the gradient ascent. If False, nothing will be printed. 

        
        returns : the parameters optimized. 
        '''
        self.extract_data(data)
        
        # we set the gradient to zero just to make sure the gradients are properly calculated
        self.full_optimizer.zero_grad()
        
        if lr is not None : # if we want to set a threshold, we set it. Ohterwise, we skip this condition and keep the actual learning_rate
            self.full_optimizer.param_groups[0]['lr'] = lr 
            
        
        stop_condition = False 
        i = 0
        old_loss = 0 
        
        while i < N_iter and stop_condition == False: 
            
            loss = train_step(self.full_optimizer, self.Y, self.covariates, self.O, self.M, self.S, self.Sigma, self.beta)
            i += 1 
            
            # condition to see if we have reach the tolerance threshold
            if max([torch.norm(param.grad) for param in self.params.values()]) < tolerance  or abs(loss - old_loss) < tolerance : #and i > 10:
                stop_condition = True 
            old_loss = loss 
            
            #update Sigma with the closed form. 
            with torch.no_grad(): 
                self.Sigma = 1/self.n*(torch.sum(torch.stack([torch.outer(self.M[i,:],self.M[i,:]) + torch.diag(self.S[i,:])  for i in range(self.n)]), axis = 0))
            
            self.MSE_Sigma_list.append(torch.mean((self.Sigma-true_Sigma)**2).item())
            self.MSE_beta_list.append(torch.mean((self.beta-true_beta)**2).item())
            self.ELBO_list.append(-loss)
            
            if verbose and i % 100 == 0 : 
                print('iteration : ', i)
                self.print_stats(loss, self.params, self.full_optimizer)
                print('-------UPDATE-------')
                print(' MSE with Sigma : ', np.round(self.MSE_Sigma_list[-1],5))
                print(' MSE with beta : ', np.round(self.MSE_beta_list[-1],5))
                print('ELBO : ', np.round(-loss.item(),5))
            


        if verbose : # just print some stats if we want to 
            if stop_condition : 
                print('---------------------------------Tolerance reached in {} iterations'.format(i))
            else : 
                print('---------------------------------Maximum number of iterations reached')
            self.print_stats(loss, [self.M,self.S,self.beta],['M','S','beta'], self.full_optimizer)   
        
        return [self.M,self.S,self.beta]

    def print_stats(self, loss, params, optimizer): 
        '''
        small function that print some stats. 
        
        It will print the actual learning rate of the optimizer, the actual log likelihood 
        and the norms of each parameter's gradient. The norm of the parameter's gradient should be low
        when we are close to the optimum. 
        '''
        print('---------------------------------lr :', optimizer.param_groups[0]['lr'])
        print('---------------------------------log likelihood :', - loss.item())
        for param_name, param in params.items(): 
            print('---------------------------------grad_{}_norm : '.format(param_name), round(torch.norm(param.grad).item(), 3))
    
    
    def VEM(self,data, number_VEM_step ,batch_size,   tolerance = 0.1, beginning_VE_step_lr = 0.002, beginning_M_step_lr = 0.01, 
                requires_init = False,N_epoch_VE = 50, N_epoch_M = 75, verbose = False): 
        '''
        function to optimize both the variational parameters and the model parameters.
        We alternate between two steps : Variational step (VE_step) and Maximization step (M_step). 
        
        
        args : 
            'number_VEM_step' : int . Number of times we want to do the VEM step, i.e. alternate between VE step and M step. 
                                The greater the better the approximation, the greater the longer time it takes. 
            
            'beginning_VE_step_lr' : float. the beginning of the learning for the VE_step. The VE will start with this lr. 
            'beginning_M_step_lr' : float. Same for beta, the M step will start with this lr. 
            
       returns : 
               M_S_lr, beta_lr : the learning rates of both steps, so that we can continue after that with the appropriate learning rates.  
        ''' 
        
        self.running_time = time.time()
        
        # we first extract the data. 
        self.extract_data(data)
        
        self.MSE_Sigma_list.append(torch.mean((self.Sigma-true_Sigma)**2).item())
        self.MSE_beta_list.append(torch.mean((self.beta-true_beta)**2).item())
        self.ELBO_list.append(1)
        
        if requires_init : 
            print('Initialisation ... ')
            clf = Poisson_reg()
            for j in range(p): 
                Y_j = self.Y[:,j]   
                O_j = self.O[:,j]
                
                clf.fit_torch(O_j,self.covariates,Y_j, verbose = False , Niter_max = 500, lr = 0.1)
                with torch.no_grad():
                    self.beta[:,j] = clf.beta
            print('Initialisation finished')
            
        # we do as many VEM_step we are asked to. 
        for i in range(number_VEM_step): 
            
            #M STEP
            # closed form for Sigma, we don't need to optimize
            with torch.no_grad(): 
                self.Sigma = 1/self.n*(torch.sum(torch.stack([torch.outer(self.M[i,:],self.M[i,:]) + torch.diag(self.S[i,:])  for i in range(self.n)]), axis = 0))
                #self.beta = torch.mm(torch.inverse(torch.mm(self.covariates.T,self.covariates)),torch.mm(self.covariates.T,self.M))
                #print('grad : ', self.grad_beta())
            #gradient ascent for beta 
            self.torch_gradient_ascent(self.M_step_optimizer, self.M_step_scheduler, 
                                       lr = beginning_M_step_lr, tolerance = tolerance, N_epoch= N_epoch_M, verbose= verbose, batch_size = batch_size )

            #VE STEP
            #gradient ascent for M and S : VE step  
            self.torch_gradient_ascent(self.VE_step_optimizer, self.VE_step_scheduler, lr = beginning_VE_step_lr,
                                    tolerance= tolerance, N_epoch= N_epoch_VE, verbose= verbose)
            
            self.MSE_Sigma_list.append(torch.mean((self.Sigma-true_Sigma)**2).item())
            self.MSE_beta_list.append(torch.mean((self.beta-true_beta)**2).item())
            self.ELBO_list.append(self.current_ELBO)
            if i %  100 == 0 : 
                print('-------UPDATE-------', batch_size, 'N_epoch :VE ',N_epoch_VE)
                print(' MSE with Sigma : ', np.round(self.MSE_Sigma_list[-1],5))
                print(' MSE with beta : ', np.round(self.MSE_beta_list[-1],5))
                print('ELBO : ', np.round(self.current_ELBO,5))

            
        self.running_time = time.time()- self.running_time
        return self.VE_step_optimizer.param_groups[0]['lr'],self.M_step_optimizer.param_groups[0]['lr']

# %%
model_batch  = PLNmodel(Sigma_init, beta_init, M_init, S_init)
model_batch.VEM(data,200,25, beginning_VE_step_lr=0.005, beginning_M_step_lr = 0.05)
#%time model_batch.VEM(data, number_VEM_step = 3,batch_size = 25, beginning_VE_step_lr=0.002, beginning_M_step_lr = 0.05, requires_init = False, )#N_epoch_VE = 100, N_epoch_M = 100)
# Out:
# VVVV_step
# -------UPDATE------- 25
#  MSE with Sigma :  0.0915
#  MSE with beta :  0.52477
# ELBO :  1073384.67198
# VVVV_step
# -------UPDATE------- 25
#  MSE with Sigma :  0.08831
#  MSE with beta :  0.49497
# ELBO :  1095285.99775
# VVVV_step
# -------UPDATE------- 25
#  MSE with Sigma :  0.07462
#  MSE with beta :  0.46063
# ELBO :  1108928.21724
# VVVV_step
# -------UPDATE------- 25
#  MSE with Sigma :  0.05746
#  MSE with beta :  0.42783
# ELBO :  1118502.67693
# VVVV_step
# -------UPDATE------- 25
#  MSE with Sigma :  0.04377
#  MSE with beta :  0.39829
# ELBO :  1124406.86916
# VVVV_step
# -------UPDATE------- 25
#  MSE with Sigma :  0.03639
#  MSE with beta :  0.37771
# ELBO :  1127775.7498
# VVVV_step
# -------UPDATE------- 25
#  MSE with Sigma :  0.03594
#  MSE with beta :  0.36272
# ELBO :  1130293.40911
# VVVV_step
# -------UPDATE------- 25
#  MSE with Sigma :  0.04153
#  MSE with beta :  0.35266
# ELBO :  1131897.14091
# VVVV_step
# -------UPDATE------- 25
#  MSE with Sigma :  0.0479
#  MSE with beta :  0.35155
# ELBO :  1132837.30474
# VVVV_step
# -------UPDATE------- 25
#  MSE with Sigma :  0.05821
#  MSE with beta :  0.35628
# ELBO :  1133558.70392
# VVVV_step
# -------UPDATE------- 25
#  MSE with Sigma :  0.0685
#  MSE with beta :  0.36285
# ELBO :  1134076.81436
# VVVV_step
# -------UPDATE------- 25
#  MSE with Sigma :  0.07904
#  MSE with beta :  0.37032
# ELBO :  1134362.71617
# VVVV_step
# -------UPDATE------- 25
#  MSE with Sigma :  0.09031
#  MSE with beta :  0.37708
# ELBO :  1134610.09164
# VVVV_step
# -------UPDATE------- 25
#  MSE with Sigma :  0.10129
#  MSE with beta :  0.38498
# ELBO :  1134790.39504
# VVVV_step
# -------UPDATE------- 25
#  MSE with Sigma :  0.11061
#  MSE with beta :  0.39002
# ELBO :  1134896.04662
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-85-53ddc9d8f26a> in <module>
#       1 model_batch  = PLNmodel(Sigma_init, beta_init, M_init, S_init)
# ----> 2 model_batch.VEM(data,200,25, beginning_VE_step_lr=0.005, beginning_M_step_lr = 0.05)
#       3 #%time model_batch.VEM(data, number_VEM_step = 3,batch_size = 25, beginning_VE_step_lr=0.002, beginning_M_step_lr = 0.05, requires_init = False, )#N_epoch_VE = 100, N_epoch_M = 100)
#
# <ipython-input-84-8cc0867f3fcf> in VEM(self, data, number_VEM_step, batch_size, tolerance, beginning_VE_step_lr, beginning_M_step_lr, requires_init, N_epoch_VE, N_epoch_M, verbose)
#     425                 #print('grad : ', self.grad_beta())
#     426             #gradient descent for beta
# --> 427             self.torch_gradient_ascent(self.M_step_optimizer, self.M_step_scheduler,
#     428                                        lr = beginning_M_step_lr, tolerance = tolerance, N_epoch= N_epoch_M, verbose= verbose, batch_size = batch_size )
#     429
#
# <ipython-input-84-8cc0867f3fcf> in torch_gradient_ascent(self, optimizer, scheduler, lr, tolerance, N_epoch, verbose, batch_size)
#     191             #print('beginning of epoch')
#     192             for Y_b, covariates_b, O_b, M_b, S_b in self.get_batch(batch_size):
# --> 193                 epoch_loss += self.train_step(optimizer, Y_b, covariates_b, O_b, M_b, S_b, self.Sigma,self.beta)
#     194             #print('epoch loss : ', epoch_loss)
#     195
#
# <ipython-input-84-8cc0867f3fcf> in train_step(self, optimizer, Y_, covariates_, O_, M_, S_, Sigma_, beta_)
#     217         loss = -self.compute_ELBO_bis(Y_, covariates_, O_, M_, S_,Sigma_,beta_)
#     218         #print('loss : ', loss)
# --> 219         loss.backward()
#     220         if torch.isnan(loss).item() == True :
#     221             print('NAAAAAAAAN')
#
# ~/anaconda3/envs/ml/lib/python3.8/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     243                 create_graph=create_graph,
#     244                 inputs=inputs)
# --> 245         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     246
#     247     def register_hook(self, hook):
#
# ~/anaconda3/envs/ml/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     143         retain_graph = create_graph
#     144
# --> 145     Variable._execution_engine.run_backward(
#     146         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     147         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %%
model_batch  = PLNmodel(Sigma_init, beta_init, M_init, S_init)
model = PLNmodel(Sigma_init, beta_init, M_init, S_init)


    
    def VEM(self,data, number_VEM_step ,batch_size,   tolerance = 0.1, beginning_VE_step_lr = 0.002, beginning_M_step_lr = 0.01, 
                requires_init = False,N_epoch_VE = 50, N_epoch_M = 75, verbose = False):
t_batch = threading.Thread(target = model_batch.VEM, args = [data, 200,25,0.005, 0.05, False, 100])
t= threading.Thread(target = model.VEM, args = [data, 200,None,0.005, 0.05, False, 100])

t_batch.start()
t.start()
t_batch.join()
t.join()

save_models(model,model_batch,25)
# Out:
#   File "<ipython-input-10-6896030969da>", line 6
#     def VEM(self,data, number_VEM_step ,batch_size,   tolerance = 0.1, beginning_VE_step_lr = 0.002, beginning_M_step_lr = 0.01,
#     ^
# IndentationError: unexpected indent

# %%
model_little  = PLNmodel(Sigma_init, beta_init, M_init, S_init)
model = PLNmodel(Sigma_init, beta_init, M_init, S_init)

t_little = threading.Thread(target = model_little.VEM, args = [data, 2000,None,0.1,0.005, 0.1, False, 10,10,False])
t= threading.Thread(target = model.VEM, args = [data, 2000,None,0.1, 0.005, 0.1, False, 100,100,False])

t_little.start()
t.start()
t_little.join()
t.join()

compare_models_nstep(model,model_little,100,10)
# Out:
# -------UPDATE------- None N_epoch :VE  10
#  MSE with Sigma :  0.13429
#  MSE with beta :  0.58658
# ELBO :  732398.29689
# -------UPDATE------- None N_epoch :VE  100
#  MSE with Sigma :  0.13429
#  MSE with beta :  0.28072
# ELBO :  824892.09693
# -------UPDATE------- None N_epoch :VE  10
#  MSE with Sigma :  0.44739
#  MSE with beta :  0.2685
# ELBO :  877602.62766
# -------UPDATE------- None N_epoch :VE  100
#  MSE with Sigma :  0.75396
#  MSE with beta :  0.20238
# ELBO :  877962.82455
# -------UPDATE------- None N_epoch :VE  10
#  MSE with Sigma :  0.54898
#  MSE with beta :  0.22169
# ELBO :  877959.89345
# -------UPDATE------- None N_epoch :VE  100
#  MSE with Sigma :  0.74103
#  MSE with beta :  0.19766
# ELBO :  877977.29219
# -------UPDATE------- None N_epoch :VE  10
#  MSE with Sigma :  0.54727
#  MSE with beta :  0.21277
# ELBO :  877977.20698
# -------UPDATE------- None N_epoch :VE  100
#  MSE with Sigma :  0.72232
#  MSE with beta :  0.19285
# ELBO :  877987.45238
# -------UPDATE------- None N_epoch :VE  10
#  MSE with Sigma :  0.54186
#  MSE with beta :  0.2036
# ELBO :  877991.30544
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-e483d28df9fa> in <module>
#       7 t_little.start()
#       8 t.start()
# ----> 9 t_little.join()
#      10 t.join()
#      11
#
# ~/anaconda3/envs/ml/lib/python3.8/threading.py in join(self, timeout)
#    1009
#    1010         if timeout is None:
# -> 1011             self._wait_for_tstate_lock()
#    1012         else:
#    1013             # the behavior of a negative timeout isn't documented, but
#
# ~/anaconda3/envs/ml/lib/python3.8/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1025         if lock is None:  # already determined that the C code is done
#    1026             assert self._is_stopped
# -> 1027         elif lock.acquire(block, timeout):
#    1028             lock.release()
#    1029             self._stop()
#
# KeyboardInterrupt:
# -------UPDATE------- None N_epoch :VE  100
#  MSE with Sigma :  0.70143
#  MSE with beta :  0.18769
# ELBO :  877995.15525
# -------UPDATE------- None N_epoch :VE  10
#  MSE with Sigma :  0.53463
#  MSE with beta :  0.19622
# ELBO :  878000.3825
# -------UPDATE------- None N_epoch :VE  100
#  MSE with Sigma :  0.68395
#  MSE with beta :  0.1826
# ELBO :  877999.87482

# %%
# Out:
# ok

# %%
model_full = PLNmodel(Sigma_init, beta_init, M_init, S_init)
# %time param_full = model_full.full_grad_ascent(data, lr = 0.005, tolerance = 0.001, N_iter = 3000, verbose = True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-24-bf551aa3be8b> in full_grad_ascent(self, data, lr, tolerance, N_iter, verbose)
#     415             self.full_optimizer.zero_grad()
#     416             loss = -self.compute_ELBO_bis(self.Y, self.covariates, self.O, self.M, self.S,self.Sigma, self.beta)
# --> 417             loss.backward()
#     418             if torch.isnan(loss).item() == True :
#     419                 print('NAN')
#
# ~/anaconda3/envs/ml/lib/python3.8/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     243                 create_graph=create_graph,
#     244                 inputs=inputs)
# --> 245         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     246
#     247     def register_hook(self, hook):
#
# ~/anaconda3/envs/ml/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     143         retain_graph = create_graph
#     144
# --> 145     Variable._execution_engine.run_backward(
#     146         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     147         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %%
model = PLNmodel(Sigma_init, beta_init, M_init, S_init)
# %time model.VEM(data, number_VEM_step = 200,batch_size = None, N_epoch_VE = 100, N_epoch_M = 100, beginning_VE_step_lr=0.005, beginning_M_step_lr = 0.1 , verbose = True)
# Out:
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 48227.98297892906
# ---------------------------------grad_M_norm :  3241.933
# ---------------------------------grad_S_norm :  244.715
# ---------------------------------grad_beta_norm :  29236.002
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 91205.59277473898
# ---------------------------------grad_M_norm :  69058.08
# ---------------------------------grad_S_norm :  4747.854
# ---------------------------------grad_beta_norm :  2441.403
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 94382.33738608417
# ---------------------------------grad_M_norm :  130516.22
# ---------------------------------grad_S_norm :  10531.189
# ---------------------------------grad_beta_norm :  831.447
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 95044.0495523533
# ---------------------------------grad_M_norm :  192050.184
# ---------------------------------grad_S_norm :  16499.052
# ---------------------------------grad_beta_norm :  303.239
# N_epoch :  100
# ---------------------------------Maximum number of iterations reached :  100
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 95242.74212905455
# ---------------------------------grad_M_norm :  251427.899
# ---------------------------------grad_S_norm :  22254.418
# ---------------------------------grad_beta_norm :  157.332
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 95247.930501419
# ---------------------------------grad_M_norm :  2490.33
# ---------------------------------grad_S_norm :  242.211
# ---------------------------------grad_beta_norm :  305.518
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 98947.42584464501
# ---------------------------------grad_M_norm :  2313.001
# ---------------------------------grad_S_norm :  56.522
# ---------------------------------grad_beta_norm :  18452.648
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 101809.03648633324
# ---------------------------------grad_M_norm :  2150.262
# ---------------------------------grad_S_norm :  16.832
# ---------------------------------grad_beta_norm :  59740.793
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 104103.44213986209
# ---------------------------------grad_M_norm :  1997.874
# ---------------------------------grad_S_norm :  4.748
# ---------------------------------grad_beta_norm :  115096.045
# N_epoch :  100
# ---------------------------------Maximum number of iterations reached :  100
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 105903.07011173642
# ---------------------------------grad_M_norm :  1857.632
# ---------------------------------grad_S_norm :  1.113
# ---------------------------------grad_beta_norm :  174876.041
# -------UPDATE------- None N_epoch :VE  100
#  MSE with Sigma :  0.13429
#  MSE with beta :  0.37809
# ELBO :  105903.07011
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 106167.41651284652
# ---------------------------------grad_M_norm :  3728.58
# ---------------------------------grad_S_norm :  44.651
# ---------------------------------grad_beta_norm :  2561.6
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 106482.12842132471
# ---------------------------------grad_M_norm :  48871.164
# ---------------------------------grad_S_norm :  1078.572
# ---------------------------------grad_beta_norm :  723.449
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 106530.36636790023
# ---------------------------------grad_M_norm :  93933.458
# ---------------------------------grad_S_norm :  2122.839
# ---------------------------------grad_beta_norm :  205.832
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 106551.99927480474
# ---------------------------------grad_M_norm :  139038.206
# ---------------------------------grad_S_norm :  3169.717
# ---------------------------------grad_beta_norm :  49.359
# N_epoch :  100
# ---------------------------------Maximum number of iterations reached :  100
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 106564.22849993069
# ---------------------------------grad_M_norm :  182322.335
# ---------------------------------grad_S_norm :  4176.425
# ---------------------------------grad_beta_norm :  34.415
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 106564.63149201224
# ---------------------------------grad_M_norm :  1803.676
# ---------------------------------grad_S_norm :  42.002
# ---------------------------------grad_beta_norm :  64.867
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 108453.19656618351
# ---------------------------------grad_M_norm :  1636.212
# ---------------------------------grad_S_norm :  7.345
# ---------------------------------grad_beta_norm :  7144.438
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 109961.37736280069
# ---------------------------------grad_M_norm :  1479.849
# ---------------------------------grad_S_norm :  1.934
# ---------------------------------grad_beta_norm :  24376.744
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 111163.35900035768
# ---------------------------------grad_M_norm :  1333.356
# ---------------------------------grad_S_norm :  0.685
# ---------------------------------grad_beta_norm :  45237.372
# N_epoch :  100
# ---------------------------------Maximum number of iterations reached :  100
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 112098.61610004785
# ---------------------------------grad_M_norm :  1201.221
# ---------------------------------grad_S_norm :  0.456
# ---------------------------------grad_beta_norm :  65024.301
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 112366.64517862606
# ---------------------------------grad_M_norm :  2410.796
# ---------------------------------grad_S_norm :  41.102
# ---------------------------------grad_beta_norm :  795.185
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 112444.93031763883
# ---------------------------------grad_M_norm :  31560.374
# ---------------------------------grad_S_norm :  1029.682
# ---------------------------------grad_beta_norm :  119.315
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 27 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 112444.89615465264
# ---------------------------------grad_M_norm :  32737.891
# ---------------------------------grad_S_norm :  1069.037
# ---------------------------------grad_beta_norm :  179.112
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 112445.19465266426
# ---------------------------------grad_M_norm :  1178.716
# ---------------------------------grad_S_norm :  39.373
# ---------------------------------grad_beta_norm :  361.275
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 113427.9721105838
# ---------------------------------grad_M_norm :  1041.281
# ---------------------------------grad_S_norm :  5.815
# ---------------------------------grad_beta_norm :  3650.818
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 114196.001608848
# ---------------------------------grad_M_norm :  915.892
# ---------------------------------grad_S_norm :  1.736
# ---------------------------------grad_beta_norm :  7581.883
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 114799.7373661081
# ---------------------------------grad_M_norm :  802.911
# ---------------------------------grad_S_norm :  0.624
# ---------------------------------grad_beta_norm :  13902.459
# N_epoch :  100
# ---------------------------------Maximum number of iterations reached :  100
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 115262.46509342513
# ---------------------------------grad_M_norm :  705.753
# ---------------------------------grad_S_norm :  0.366
# ---------------------------------grad_beta_norm :  22362.6
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 115377.63517905795
# ---------------------------------grad_M_norm :  1413.239
# ---------------------------------grad_S_norm :  23.348
# ---------------------------------grad_beta_norm :  463.785
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 22 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 115412.52736370936
# ---------------------------------grad_M_norm :  16494.675
# ---------------------------------grad_S_norm :  515.487
# ---------------------------------grad_beta_norm :  143.527
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 115412.81671698515
# ---------------------------------grad_M_norm :  736.334
# ---------------------------------grad_S_norm :  23.537
# ---------------------------------grad_beta_norm :  182.304
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 115878.53578380063
# ---------------------------------grad_M_norm :  634.354
# ---------------------------------grad_S_norm :  3.984
# ---------------------------------grad_beta_norm :  3855.765
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 116234.23267622743
# ---------------------------------grad_M_norm :  543.381
# ---------------------------------grad_S_norm :  1.162
# ---------------------------------grad_beta_norm :  12642.982
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 116509.83414926229
# ---------------------------------grad_M_norm :  466.086
# ---------------------------------grad_S_norm :  0.433
# ---------------------------------grad_beta_norm :  25644.0
# N_epoch :  100
# ---------------------------------Maximum number of iterations reached :  100
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 116718.6604771693
# ---------------------------------grad_M_norm :  403.147
# ---------------------------------grad_S_norm :  0.285
# ---------------------------------grad_beta_norm :  41181.697
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 116766.31193758857
# ---------------------------------grad_M_norm :  806.719
# ---------------------------------grad_S_norm :  13.408
# ---------------------------------grad_beta_norm :  708.99
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 116789.21018999764
# ---------------------------------grad_M_norm :  11978.125
# ---------------------------------grad_S_norm :  375.802
# ---------------------------------grad_beta_norm :  236.557
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 33 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 116790.61293867658
# ---------------------------------grad_M_norm :  15167.058
# ---------------------------------grad_S_norm :  477.882
# ---------------------------------grad_beta_norm :  127.093
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 116790.6336970588
# ---------------------------------grad_M_norm :  458.989
# ---------------------------------grad_S_norm :  14.589
# ---------------------------------grad_beta_norm :  266.914
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117001.54492145531
# ---------------------------------grad_M_norm :  385.52
# ---------------------------------grad_S_norm :  2.636
# ---------------------------------grad_beta_norm :  2623.581
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117158.51906381921
# ---------------------------------grad_M_norm :  321.352
# ---------------------------------grad_S_norm :  0.819
# ---------------------------------grad_beta_norm :  11457.087
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117278.15396151436
# ---------------------------------grad_M_norm :  270.872
# ---------------------------------grad_S_norm :  0.299
# ---------------------------------grad_beta_norm :  25062.566
# N_epoch :  100
# ---------------------------------Maximum number of iterations reached :  100
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117368.27586564858
# ---------------------------------grad_M_norm :  232.508
# ---------------------------------grad_S_norm :  0.218
# ---------------------------------grad_beta_norm :  40816.945
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 117388.7984266589
# ---------------------------------grad_M_norm :  465.194
# ---------------------------------grad_S_norm :  8.161
# ---------------------------------grad_beta_norm :  700.569
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 117405.41555680467
# ---------------------------------grad_M_norm :  7421.961
# ---------------------------------grad_S_norm :  250.826
# ---------------------------------grad_beta_norm :  143.872
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 27 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 117405.48290092497
# ---------------------------------grad_M_norm :  7715.765
# ---------------------------------grad_S_norm :  260.778
# ---------------------------------grad_beta_norm :  127.573
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117405.40845447796
# ---------------------------------grad_M_norm :  299.167
# ---------------------------------grad_S_norm :  10.118
# ---------------------------------grad_beta_norm :  314.931
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117502.85786519949
# ---------------------------------grad_M_norm :  244.461
# ---------------------------------grad_S_norm :  1.933
# ---------------------------------grad_beta_norm :  1685.631
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117573.76184210846
# ---------------------------------grad_M_norm :  197.58
# ---------------------------------grad_S_norm :  0.61
# ---------------------------------grad_beta_norm :  8427.733
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117627.10335928941
# ---------------------------------grad_M_norm :  164.391
# ---------------------------------grad_S_norm :  0.213
# ---------------------------------grad_beta_norm :  20166.093
# N_epoch :  100
# ---------------------------------Maximum number of iterations reached :  100
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117667.58169634825
# ---------------------------------grad_M_norm :  141.464
# ---------------------------------grad_S_norm :  0.168
# ---------------------------------grad_beta_norm :  33649.164
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 117676.87424464694
# ---------------------------------grad_M_norm :  283.063
# ---------------------------------grad_S_norm :  5.468
# ---------------------------------grad_beta_norm :  594.217
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 13 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 117686.14006941582
# ---------------------------------grad_M_norm :  2433.169
# ---------------------------------grad_S_norm :  88.777
# ---------------------------------grad_beta_norm :  342.56
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117687.72724242938
# ---------------------------------grad_M_norm :  183.369
# ---------------------------------grad_S_norm :  6.945
# ---------------------------------grad_beta_norm :  294.34
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117733.14531404387
# ---------------------------------grad_M_norm :  149.381
# ---------------------------------grad_S_norm :  1.282
# ---------------------------------grad_beta_norm :  4509.293
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117766.25073761221
# ---------------------------------grad_M_norm :  122.001
# ---------------------------------grad_S_norm :  0.415
# ---------------------------------grad_beta_norm :  13536.79
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117791.92205996427
# ---------------------------------grad_M_norm :  104.139
# ---------------------------------grad_S_norm :  0.164
# ---------------------------------grad_beta_norm :  25078.209
# N_epoch :  100
# ---------------------------------Maximum number of iterations reached :  100
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117812.13870653184
# ---------------------------------grad_M_norm :  92.426
# ---------------------------------grad_S_norm :  0.131
# ---------------------------------grad_beta_norm :  37207.905
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 117816.73932392808
# ---------------------------------grad_M_norm :  185.017
# ---------------------------------grad_S_norm :  4.073
# ---------------------------------grad_beta_norm :  518.096
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 9 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 117823.66534766337
# ---------------------------------grad_M_norm :  1186.028
# ---------------------------------grad_S_norm :  47.171
# ---------------------------------grad_beta_norm :  236.482
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117823.38568558611
# ---------------------------------grad_M_norm :  120.234
# ---------------------------------grad_S_norm :  5.008
# ---------------------------------grad_beta_norm :  271.451
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117847.0596151514
# ---------------------------------grad_M_norm :  98.989
# ---------------------------------grad_S_norm :  0.869
# ---------------------------------grad_beta_norm :  6703.689
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117864.53990663125
# ---------------------------------grad_M_norm :  82.505
# ---------------------------------grad_S_norm :  0.292
# ---------------------------------grad_beta_norm :  15534.044
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117878.58544331131
# ---------------------------------grad_M_norm :  72.494
# ---------------------------------grad_S_norm :  0.13
# ---------------------------------grad_beta_norm :  25743.036
# N_epoch :  100
# ---------------------------------Maximum number of iterations reached :  100
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117890.05106426775
# ---------------------------------grad_M_norm :  66.116
# ---------------------------------grad_S_norm :  0.104
# ---------------------------------grad_beta_norm :  36014.135
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 117892.59654084727
# ---------------------------------grad_M_norm :  132.374
# ---------------------------------grad_S_norm :  3.315
# ---------------------------------grad_beta_norm :  432.927
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 8 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 117898.16020951883
# ---------------------------------grad_M_norm :  774.438
# ---------------------------------grad_S_norm :  34.152
# ---------------------------------grad_beta_norm :  256.493
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117898.6811260154
# ---------------------------------grad_M_norm :  112.008
# ---------------------------------grad_S_norm :  4.647
# ---------------------------------grad_beta_norm :  434.956
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117915.09339469766
# ---------------------------------grad_M_norm :  85.819
# ---------------------------------grad_S_norm :  0.954
# ---------------------------------grad_beta_norm :  2585.014
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117926.29648445308
# ---------------------------------grad_M_norm :  65.458
# ---------------------------------grad_S_norm :  0.283
# ---------------------------------grad_beta_norm :  5494.376
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117934.83960977913
# ---------------------------------grad_M_norm :  55.294
# ---------------------------------grad_S_norm :  0.105
# ---------------------------------grad_beta_norm :  11672.346
# N_epoch :  100
# ---------------------------------Maximum number of iterations reached :  100
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117941.75945859721
# ---------------------------------grad_M_norm :  49.93
# ---------------------------------grad_S_norm :  0.083
# ---------------------------------grad_beta_norm :  18774.337
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 117943.3315900569
# ---------------------------------grad_M_norm :  99.947
# ---------------------------------grad_S_norm :  2.858
# ---------------------------------grad_beta_norm :  314.21
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 17 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 117948.47456824307
# ---------------------------------grad_M_norm :  1288.726
# ---------------------------------grad_S_norm :  60.729
# ---------------------------------grad_beta_norm :  138.591
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117948.75409061008
# ---------------------------------grad_M_norm :  84.361
# ---------------------------------grad_S_norm :  3.922
# ---------------------------------grad_beta_norm :  217.705
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117960.01066921932
# ---------------------------------grad_M_norm :  63.547
# ---------------------------------grad_S_norm :  0.889
# ---------------------------------grad_beta_norm :  1236.846
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117967.25766125698
# ---------------------------------grad_M_norm :  48.838
# ---------------------------------grad_S_norm :  0.233
# ---------------------------------grad_beta_norm :  5097.663
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117972.69871528362
# ---------------------------------grad_M_norm :  42.119
# ---------------------------------grad_S_norm :  0.087
# ---------------------------------grad_beta_norm :  10780.63
# N_epoch :  100
# ---------------------------------Maximum number of iterations reached :  100
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117977.12262214503
# ---------------------------------grad_M_norm :  38.584
# ---------------------------------grad_S_norm :  0.067
# ---------------------------------grad_beta_norm :  16781.783
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 117978.13768283042
# ---------------------------------grad_M_norm :  77.238
# ---------------------------------grad_S_norm :  2.464
# ---------------------------------grad_beta_norm :  255.942
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 14 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 117981.90284014192
# ---------------------------------grad_M_norm :  774.459
# ---------------------------------grad_S_norm :  40.857
# ---------------------------------grad_beta_norm :  87.206
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117981.84273793286
# ---------------------------------grad_M_norm :  57.551
# ---------------------------------grad_S_norm :  3.148
# ---------------------------------grad_beta_norm :  200.269
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117988.95800245498
# ---------------------------------grad_M_norm :  44.972
# ---------------------------------grad_S_norm :  0.592
# ---------------------------------grad_beta_norm :  3283.197
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117993.50229188839
# ---------------------------------grad_M_norm :  36.713
# ---------------------------------grad_S_norm :  0.161
# ---------------------------------grad_beta_norm :  7758.781
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117997.02093046407
# ---------------------------------grad_M_norm :  32.816
# ---------------------------------grad_S_norm :  0.074
# ---------------------------------grad_beta_norm :  12980.758
# N_epoch :  100
# ---------------------------------Maximum number of iterations reached :  100
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 117999.93559622223
# ---------------------------------grad_M_norm :  30.566
# ---------------------------------grad_S_norm :  0.055
# ---------------------------------grad_beta_norm :  18190.726
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118000.68461594371
# ---------------------------------grad_M_norm :  61.203
# ---------------------------------grad_S_norm :  2.173
# ---------------------------------grad_beta_norm :  219.808
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 3 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118001.69490004101
# ---------------------------------grad_M_norm :  147.633
# ---------------------------------grad_S_norm :  7.236
# ---------------------------------grad_beta_norm :  205.56
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118002.13386257066
# ---------------------------------grad_M_norm :  46.329
# ---------------------------------grad_S_norm :  2.772
# ---------------------------------grad_beta_norm :  248.254
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118007.29254504696
# ---------------------------------grad_M_norm :  34.884
# ---------------------------------grad_S_norm :  0.445
# ---------------------------------grad_beta_norm :  1546.529
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118010.26497291026
# ---------------------------------grad_M_norm :  28.433
# ---------------------------------grad_S_norm :  0.177
# ---------------------------------grad_beta_norm :  4736.383
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 53 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118010.46579593312
# ---------------------------------grad_M_norm :  28.146
# ---------------------------------grad_S_norm :  0.133
# ---------------------------------grad_beta_norm :  5052.07
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118011.03042340548
# ---------------------------------grad_M_norm :  56.247
# ---------------------------------grad_S_norm :  1.906
# ---------------------------------grad_beta_norm :  165.777
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 3 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118011.80436251838
# ---------------------------------grad_M_norm :  129.176
# ---------------------------------grad_S_norm :  6.254
# ---------------------------------grad_beta_norm :  115.393
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118011.66799240191
# ---------------------------------grad_M_norm :  52.58
# ---------------------------------grad_S_norm :  2.616
# ---------------------------------grad_beta_norm :  269.206
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118016.90880263937
# ---------------------------------grad_M_norm :  35.455
# ---------------------------------grad_S_norm :  0.468
# ---------------------------------grad_beta_norm :  1500.426
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 41 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118018.65180330002
# ---------------------------------grad_M_norm :  28.732
# ---------------------------------grad_S_norm :  0.255
# ---------------------------------grad_beta_norm :  1268.071
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118019.11751740672
# ---------------------------------grad_M_norm :  57.218
# ---------------------------------grad_S_norm :  1.974
# ---------------------------------grad_beta_norm :  105.861
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 3 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118019.68441859988
# ---------------------------------grad_M_norm :  139.932
# ---------------------------------grad_S_norm :  5.886
# ---------------------------------grad_beta_norm :  114.727
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118019.86190433138
# ---------------------------------grad_M_norm :  40.184
# ---------------------------------grad_S_norm :  2.101
# ---------------------------------grad_beta_norm :  133.735
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118023.66194135939
# ---------------------------------grad_M_norm :  28.453
# ---------------------------------grad_S_norm :  0.429
# ---------------------------------grad_beta_norm :  1555.355
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 29 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118023.96878652599
# ---------------------------------grad_M_norm :  27.489
# ---------------------------------grad_S_norm :  0.251
# ---------------------------------grad_beta_norm :  1815.81
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118024.40693672295
# ---------------------------------grad_M_norm :  54.723
# ---------------------------------grad_S_norm :  1.586
# ---------------------------------grad_beta_norm :  103.149
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 4 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118024.99342631748
# ---------------------------------grad_M_norm :  165.221
# ---------------------------------grad_S_norm :  6.62
# ---------------------------------grad_beta_norm :  95.748
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118025.20525610483
# ---------------------------------grad_M_norm :  39.259
# ---------------------------------grad_S_norm :  1.8
# ---------------------------------grad_beta_norm :  111.133
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 25 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118028.57996899587
# ---------------------------------grad_M_norm :  27.73
# ---------------------------------grad_S_norm :  0.464
# ---------------------------------grad_beta_norm :  1269.978
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118028.89982769563
# ---------------------------------grad_M_norm :  55.131
# ---------------------------------grad_S_norm :  1.885
# ---------------------------------grad_beta_norm :  88.173
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 6 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118029.68390297292
# ---------------------------------grad_M_norm :  233.088
# ---------------------------------grad_S_norm :  9.503
# ---------------------------------grad_beta_norm :  72.694
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118029.84544918737
# ---------------------------------grad_M_norm :  39.871
# ---------------------------------grad_S_norm :  1.632
# ---------------------------------grad_beta_norm :  86.787
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 21 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118032.58001352091
# ---------------------------------grad_M_norm :  28.819
# ---------------------------------grad_S_norm :  0.31
# ---------------------------------grad_beta_norm :  878.285
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118032.91442444954
# ---------------------------------grad_M_norm :  57.206
# ---------------------------------grad_S_norm :  1.561
# ---------------------------------grad_beta_norm :  72.964
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 5 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118033.40447608673
# ---------------------------------grad_M_norm :  195.941
# ---------------------------------grad_S_norm :  7.12
# ---------------------------------grad_beta_norm :  99.933
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118033.59209308986
# ---------------------------------grad_M_norm :  38.298
# ---------------------------------grad_S_norm :  1.484
# ---------------------------------grad_beta_norm :  97.363
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 20 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118036.03201885358
# ---------------------------------grad_M_norm :  27.495
# ---------------------------------grad_S_norm :  0.341
# ---------------------------------grad_beta_norm :  688.564
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118036.42636189502
# ---------------------------------grad_M_norm :  54.561
# ---------------------------------grad_S_norm :  1.081
# ---------------------------------grad_beta_norm :  66.851
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118036.44898273585
# ---------------------------------grad_M_norm :  92.544
# ---------------------------------grad_S_norm :  2.321
# ---------------------------------grad_beta_norm :  131.704
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118036.68679590368
# ---------------------------------grad_M_norm :  39.063
# ---------------------------------grad_S_norm :  1.312
# ---------------------------------grad_beta_norm :  226.976
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 11 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118038.02572013137
# ---------------------------------grad_M_norm :  32.468
# ---------------------------------grad_S_norm :  0.413
# ---------------------------------grad_beta_norm :  837.527
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118038.4098713358
# ---------------------------------grad_M_norm :  64.311
# ---------------------------------grad_S_norm :  0.968
# ---------------------------------grad_beta_norm :  33.262
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 3 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118038.65686125305
# ---------------------------------grad_M_norm :  124.988
# ---------------------------------grad_S_norm :  2.92
# ---------------------------------grad_beta_norm :  45.005
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118038.75733974032
# ---------------------------------grad_M_norm :  36.398
# ---------------------------------grad_S_norm :  1.081
# ---------------------------------grad_beta_norm :  62.871
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 11 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118040.09303167599
# ---------------------------------grad_M_norm :  29.792
# ---------------------------------grad_S_norm :  0.552
# ---------------------------------grad_beta_norm :  257.49
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118040.52605885267
# ---------------------------------grad_M_norm :  59.004
# ---------------------------------grad_S_norm :  0.661
# ---------------------------------grad_beta_norm :  25.0
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118040.61000962027
# ---------------------------------grad_M_norm :  93.852
# ---------------------------------grad_S_norm :  1.376
# ---------------------------------grad_beta_norm :  65.197
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118040.75457607325
# ---------------------------------grad_M_norm :  34.29
# ---------------------------------grad_S_norm :  0.838
# ---------------------------------grad_beta_norm :  104.003
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 10 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118041.86933731414
# ---------------------------------grad_M_norm :  28.653
# ---------------------------------grad_S_norm :  0.274
# ---------------------------------grad_beta_norm :  274.184
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118042.14552784657
# ---------------------------------grad_M_norm :  56.758
# ---------------------------------grad_S_norm :  0.667
# ---------------------------------grad_beta_norm :  27.531
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 4 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118042.49149269416
# ---------------------------------grad_M_norm :  149.968
# ---------------------------------grad_S_norm :  2.742
# ---------------------------------grad_beta_norm :  28.065
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118042.58795837998
# ---------------------------------grad_M_norm :  32.793
# ---------------------------------grad_S_norm :  0.773
# ---------------------------------grad_beta_norm :  44.402
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 10 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118043.68051668505
# ---------------------------------grad_M_norm :  27.588
# ---------------------------------grad_S_norm :  0.328
# ---------------------------------grad_beta_norm :  215.823
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118043.94911348741
# ---------------------------------grad_M_norm :  54.666
# ---------------------------------grad_S_norm :  0.565
# ---------------------------------grad_beta_norm :  39.033
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 3 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118044.16858769242
# ---------------------------------grad_M_norm :  116.373
# ---------------------------------grad_S_norm :  1.688
# ---------------------------------grad_beta_norm :  33.33
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118044.26003760312
# ---------------------------------grad_M_norm :  31.777
# ---------------------------------grad_S_norm :  0.644
# ---------------------------------grad_beta_norm :  44.931
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 9 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118045.1952243444
# ---------------------------------grad_M_norm :  27.29
# ---------------------------------grad_S_norm :  0.228
# ---------------------------------grad_beta_norm :  138.57
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118045.39900732938
# ---------------------------------grad_M_norm :  54.076
# ---------------------------------grad_S_norm :  0.569
# ---------------------------------grad_beta_norm :  32.938
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 3 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118045.60140475995
# ---------------------------------grad_M_norm :  114.161
# ---------------------------------grad_S_norm :  1.606
# ---------------------------------grad_beta_norm :  26.864
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118045.68217730924
# ---------------------------------grad_M_norm :  31.946
# ---------------------------------grad_S_norm :  0.598
# ---------------------------------grad_beta_norm :  47.913
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 9 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118046.6013149474
# ---------------------------------grad_M_norm :  27.388
# ---------------------------------grad_S_norm :  0.222
# ---------------------------------grad_beta_norm :  136.647
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118046.79392894387
# ---------------------------------grad_M_norm :  54.255
# ---------------------------------grad_S_norm :  0.483
# ---------------------------------grad_beta_norm :  27.942
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 3 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118046.98412006415
# ---------------------------------grad_M_norm :  114.49
# ---------------------------------grad_S_norm :  1.389
# ---------------------------------grad_beta_norm :  25.764
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118047.06455384372
# ---------------------------------grad_M_norm :  30.779
# ---------------------------------grad_S_norm :  0.519
# ---------------------------------grad_beta_norm :  38.006
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 8 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118047.84333897522
# ---------------------------------grad_M_norm :  26.869
# ---------------------------------grad_S_norm :  0.198
# ---------------------------------grad_beta_norm :  134.311
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118048.00079909168
# ---------------------------------grad_M_norm :  53.227
# ---------------------------------grad_S_norm :  0.481
# ---------------------------------grad_beta_norm :  30.774
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 3 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118048.18124328331
# ---------------------------------grad_M_norm :  112.122
# ---------------------------------grad_S_norm :  1.273
# ---------------------------------grad_beta_norm :  26.629
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118048.26178822534
# ---------------------------------grad_M_norm :  30.615
# ---------------------------------grad_S_norm :  0.46
# ---------------------------------grad_beta_norm :  41.411
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 7 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118048.9181528205
# ---------------------------------grad_M_norm :  27.232
# ---------------------------------grad_S_norm :  0.226
# ---------------------------------grad_beta_norm :  95.093
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118049.05850282793
# ---------------------------------grad_M_norm :  53.937
# ---------------------------------grad_S_norm :  0.496
# ---------------------------------grad_beta_norm :  22.697
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118049.15151658375
# ---------------------------------grad_M_norm :  82.145
# ---------------------------------grad_S_norm :  0.81
# ---------------------------------grad_beta_norm :  13.836
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118049.22810072846
# ---------------------------------grad_M_norm :  30.003
# ---------------------------------grad_S_norm :  0.365
# ---------------------------------grad_beta_norm :  27.037
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 6 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118049.7563228619
# ---------------------------------grad_M_norm :  27.178
# ---------------------------------grad_S_norm :  0.168
# ---------------------------------grad_beta_norm :  89.676
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118049.88101708813
# ---------------------------------grad_M_norm :  53.821
# ---------------------------------grad_S_norm :  0.432
# ---------------------------------grad_beta_norm :  19.197
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118049.96925768304
# ---------------------------------grad_M_norm :  83.09
# ---------------------------------grad_S_norm :  0.73
# ---------------------------------grad_beta_norm :  23.789
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118050.04156606141
# ---------------------------------grad_M_norm :  29.906
# ---------------------------------grad_S_norm :  0.36
# ---------------------------------grad_beta_norm :  44.487
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 6 iterations
# ---------------------------------lr : 0.005
# ...
# ---------------------------------grad_S_norm :  0.028
# ---------------------------------grad_beta_norm :  9.684
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118081.97280272581
# ---------------------------------grad_M_norm :  16.591
# ---------------------------------grad_S_norm :  0.027
# ---------------------------------grad_beta_norm :  12.697
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118082.01631214585
# ---------------------------------grad_M_norm :  32.754
# ---------------------------------grad_S_norm :  0.064
# ---------------------------------grad_beta_norm :  5.624
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118082.02798703073
# ---------------------------------grad_M_norm :  49.539
# ---------------------------------grad_S_norm :  0.082
# ---------------------------------grad_beta_norm :  5.056
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118082.03855172571
# ---------------------------------grad_M_norm :  16.98
# ---------------------------------grad_S_norm :  0.028
# ---------------------------------grad_beta_norm :  9.657
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118082.08341664713
# ---------------------------------grad_M_norm :  16.545
# ---------------------------------grad_S_norm :  0.027
# ---------------------------------grad_beta_norm :  12.651
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118082.12674396779
# ---------------------------------grad_M_norm :  32.662
# ---------------------------------grad_S_norm :  0.064
# ---------------------------------grad_beta_norm :  5.616
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118082.13834528449
# ---------------------------------grad_M_norm :  49.403
# ---------------------------------grad_S_norm :  0.082
# ---------------------------------grad_beta_norm :  5.049
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118082.14884108264
# ---------------------------------grad_M_norm :  16.933
# ---------------------------------grad_S_norm :  0.028
# ---------------------------------grad_beta_norm :  9.63
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118082.1935210075
# ---------------------------------grad_M_norm :  16.499
# ---------------------------------grad_S_norm :  0.027
# ---------------------------------grad_beta_norm :  12.605
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118082.23666753576
# ---------------------------------grad_M_norm :  32.571
# ---------------------------------grad_S_norm :  0.064
# ---------------------------------grad_beta_norm :  5.607
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118082.24819580799
# ---------------------------------grad_M_norm :  49.267
# ---------------------------------grad_S_norm :  0.082
# ---------------------------------grad_beta_norm :  5.042
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118082.25862321169
# ---------------------------------grad_M_norm :  16.887
# ---------------------------------grad_S_norm :  0.028
# ---------------------------------grad_beta_norm :  9.604
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118082.30311946775
# ---------------------------------grad_M_norm :  16.454
# ---------------------------------grad_S_norm :  0.026
# ---------------------------------grad_beta_norm :  12.56
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118082.34608650017
# ---------------------------------grad_M_norm :  32.481
# ---------------------------------grad_S_norm :  0.064
# ---------------------------------grad_beta_norm :  5.599
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118082.35754224587
# ---------------------------------grad_M_norm :  49.131
# ---------------------------------grad_S_norm :  0.082
# ---------------------------------grad_beta_norm :  5.034
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118082.36790175198
# ---------------------------------grad_M_norm :  16.841
# ---------------------------------grad_S_norm :  0.028
# ---------------------------------grad_beta_norm :  9.578
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118082.41221565641
# ---------------------------------grad_M_norm :  16.409
# ---------------------------------grad_S_norm :  0.026
# ---------------------------------grad_beta_norm :  12.514
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118082.4550044787
# ---------------------------------grad_M_norm :  32.391
# ---------------------------------grad_S_norm :  0.063
# ---------------------------------grad_beta_norm :  5.591
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118082.46638821012
# ---------------------------------grad_M_norm :  48.997
# ---------------------------------grad_S_norm :  0.081
# ---------------------------------grad_beta_norm :  5.027
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118082.47668031036
# ---------------------------------grad_M_norm :  16.795
# ---------------------------------grad_S_norm :  0.028
# ---------------------------------grad_beta_norm :  9.552
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118082.52081316907
# ---------------------------------grad_M_norm :  16.363
# ---------------------------------grad_S_norm :  0.026
# ---------------------------------grad_beta_norm :  12.469
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118082.56342505752
# ---------------------------------grad_M_norm :  32.301
# ---------------------------------grad_S_norm :  0.063
# ---------------------------------grad_beta_norm :  5.583
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118082.57473728148
# ---------------------------------grad_M_norm :  48.863
# ---------------------------------grad_S_norm :  0.081
# ---------------------------------grad_beta_norm :  5.021
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118082.58496246231
# ---------------------------------grad_M_norm :  16.75
# ---------------------------------grad_S_norm :  0.028
# ---------------------------------grad_beta_norm :  9.526
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118082.62891557172
# ---------------------------------grad_M_norm :  16.319
# ---------------------------------grad_S_norm :  0.026
# ---------------------------------grad_beta_norm :  12.424
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118082.67135179156
# ---------------------------------grad_M_norm :  32.212
# ---------------------------------grad_S_norm :  0.063
# ---------------------------------grad_beta_norm :  5.576
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118082.68259300948
# ---------------------------------grad_M_norm :  48.73
# ---------------------------------grad_S_norm :  0.081
# ---------------------------------grad_beta_norm :  5.014
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118082.69275175242
# ---------------------------------grad_M_norm :  16.705
# ---------------------------------grad_S_norm :  0.027
# ---------------------------------grad_beta_norm :  9.5
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118082.73652639739
# ---------------------------------grad_M_norm :  16.274
# ---------------------------------grad_S_norm :  0.026
# ---------------------------------grad_beta_norm :  12.38
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118082.77878820406
# ---------------------------------grad_M_norm :  32.123
# ---------------------------------grad_S_norm :  0.063
# ---------------------------------grad_beta_norm :  5.568
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118082.7899589121
# ---------------------------------grad_M_norm :  48.597
# ---------------------------------grad_S_norm :  0.081
# ---------------------------------grad_beta_norm :  5.007
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118082.80005169351
# ---------------------------------grad_M_norm :  16.66
# ---------------------------------grad_S_norm :  0.027
# ---------------------------------grad_beta_norm :  9.474
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118082.84364915005
# ---------------------------------grad_M_norm :  16.229
# ---------------------------------grad_S_norm :  0.026
# ---------------------------------grad_beta_norm :  12.335
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118082.88573778933
# ---------------------------------grad_M_norm :  32.035
# ---------------------------------grad_S_norm :  0.063
# ---------------------------------grad_beta_norm :  5.561
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118082.89683847837
# ---------------------------------grad_M_norm :  48.465
# ---------------------------------grad_S_norm :  0.081
# ---------------------------------grad_beta_norm :  5.001
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118082.90686576987
# ---------------------------------grad_M_norm :  16.615
# ---------------------------------grad_S_norm :  0.027
# ---------------------------------grad_beta_norm :  9.449
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118082.95028730217
# ---------------------------------grad_M_norm :  16.185
# ---------------------------------grad_S_norm :  0.026
# ---------------------------------grad_beta_norm :  12.291
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118082.99220400972
# ---------------------------------grad_M_norm :  31.947
# ---------------------------------grad_S_norm :  0.063
# ---------------------------------grad_beta_norm :  5.553
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118083.00323516557
# ---------------------------------grad_M_norm :  48.334
# ---------------------------------grad_S_norm :  0.08
# ---------------------------------grad_beta_norm :  4.994
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118083.01319743392
# ---------------------------------grad_M_norm :  16.57
# ---------------------------------grad_S_norm :  0.027
# ---------------------------------grad_beta_norm :  9.424
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118083.05644429737
# ---------------------------------grad_M_norm :  16.141
# ---------------------------------grad_S_norm :  0.026
# ---------------------------------grad_beta_norm :  12.247
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118083.0981902985
# ---------------------------------grad_M_norm :  31.86
# ---------------------------------grad_S_norm :  0.063
# ---------------------------------grad_beta_norm :  5.546
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118083.10915240203
# ---------------------------------grad_M_norm :  48.203
# ---------------------------------grad_S_norm :  0.08
# ---------------------------------grad_beta_norm :  4.988
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118083.11905010926
# ---------------------------------grad_M_norm :  16.526
# ---------------------------------grad_S_norm :  0.027
# ---------------------------------grad_beta_norm :  9.398
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118083.1621235491
# ---------------------------------grad_M_norm :  16.097
# ---------------------------------grad_S_norm :  0.026
# ---------------------------------grad_beta_norm :  12.203
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118083.2037000599
# ---------------------------------grad_M_norm :  31.773
# ---------------------------------grad_S_norm :  0.062
# ---------------------------------grad_beta_norm :  5.539
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.1
# ---------------------------------log likelihood : 118083.21459358695
# ---------------------------------grad_M_norm :  48.073
# ---------------------------------grad_S_norm :  0.08
# ---------------------------------grad_beta_norm :  4.982
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118083.22442719055
# ---------------------------------grad_M_norm :  16.482
# ---------------------------------grad_S_norm :  0.027
# ---------------------------------grad_beta_norm :  9.373
# N_epoch :  100
# ---------------------------------Tolerance 0.1 reached in 2 iterations
# ---------------------------------lr : 0.005
# ---------------------------------log likelihood : 118083.26732844149
# ---------------------------------grad_M_norm :  16.054
# ---------------------------------grad_S_norm :  0.026
# ---------------------------------grad_beta_norm :  12.159
# CPU times: user 3min 37s, sys: 500 ms, total: 3min 38s
# Wall time: 1min 24s
# (0.005, 0.1)

# %%
model.running_time
# Out:
# 84.9903552532196

# %%
#extraction des données 
Y_tricho = torch.from_numpy(read_csv('trichoptera.csv', sep=',').to_numpy())
O_tricho = torch.outer(Y_tricho.sum(1), torch.ones(Y_tricho.shape[1]))/1000

n_tricho,p_tricho = Y_tricho.shape 
d_tricho = 4
covariates_tricho = torch.ones((n_tricho,d_tricho)) # attention prendre que des 1 n'est pas une bonne solution

data_tricho = [Y_tricho,O_tricho, covariates_tricho]

# %%
d = 10 # nb of cavariates
n = 150; p = 10

# %%
true_Sigma = torch.from_numpy(toeplitz(0.5**np.arange(p)))
true_beta = torch.randn(d, p)


covariates = torch.rand((n,d))
O = 1 + torch.zeros((n,p))

sample_model = sample_PLN()
Y_sampled = torch.from_numpy(sample_model.sample(true_Sigma,true_beta, O, covariates)) 

data = [Y_sampled, O, covariates]

# %%
torch.manual_seed(1)

noise = torch.randn(p,p) 
Sigma_init =  (noise+ noise.T)
beta_init = torch.rand((d, p))

M_init = torch.ones((n,p))/100# some random values to initialize we divide to avoid nan values 
S_init = torch.ones((n,p))/8 # some random values to initializ. we divise to avoid nan values

# %%
def save_model(modele, batch_size, time): 
    n,p = modele.Y.shape
    d = modele.beta.shape[0]
    ELBO = np.round(modele.current_ELBO,5)
    name = 'batch size = {},n = {}, p = {}, d = {},  ELBO ={}, time = {}.png'.format(batch_size, n,p,d, ELBO, time )
    abscisse = np.arange(len(modele.MSE_Sigma_list))
    fig,ax = plt.subplots(4,1,figsize = (12,12))
    plt.subplots_adjust(hspace = 0.4)
    plt.suptitle(name)
    ax[0].plot(abscisse, modele.MSE_Sigma_list)
    Sigma_min = np.round(min(modele.MSE_Sigma_list),5)
    Sigma_argmin = np.argmin(modele.MSE_Sigma_list)
    ax[0].set_title('MSE of Sigma. last MSE :{} . best_MSE {}, argmin = {}'.format(np.round(modele.MSE_Sigma_list[-1],5), Sigma_min, Sigma_argmin))
    
    ax[1].plot(abscisse, modele.MSE_beta_list)
    beta_min = np.round(min(modele.MSE_beta_list),5)
    beta_argmin = np.argmin(modele.MSE_beta_list)
    ax[1].set_title('MSE of beta. last MSE :{} . best_MSE {}, argmin = {}'.format(np.round(modele.MSE_beta_list[-1],5), beta_min, beta_argmin))
    
    ax[2].plot(abscisse, modele.ELBO_list)
    ax[2].set_xscale('log')
    ax[2].set_title('ELBO')
    
    ax[3].plot(abscisse, modele.MSE_Sigma_list)
    ax[3].set_title('MSE of Sigma (x axis in log scale)')
    ax[3].set_xscale('log')
    plt.savefig(name)
    

    
def compare_models_batch(modele,modele_batch, batch_size): 
    n,p = modele.Y.shape
    d = modele.beta.shape[0]
    ELBO = np.round(modele.current_ELBO,5)
    name = 'batch size = {},n = {}, p = {}, d = {}, With batch : last ELBO : {}, time : {}, Without batch : last ELBO : {}, time : {}.jpg'.format(batch_size,
                                         n,p,d,  np.round(modele_batch.current_ELBO,1), np.round(modele_batch.running_time,0),  np.round(modele.current_ELBO,1),np.round(modele.running_time,0))
    abscisse = np.arange(len(modele.MSE_Sigma_list))
    fig,ax = plt.subplots(4,1,figsize = (15,12))
    plt.subplots_adjust(hspace = 0.4)
    plt.suptitle(name)
    ax[0].plot(abscisse, modele_batch.MSE_Sigma_list, label = 'MSE with batch')
    ax[0].plot(abscisse, modele.MSE_Sigma_list, label = 'MSE without batch')
    ax[0].legend()
    ax[0].set_ybound( lower=0, upper=0.7)
    ax[0].set_title('MSE of Sigma. last MSE with batch :{} . last_MSE without batch : {}'.format(np.round(modele_batch.MSE_Sigma_list[-1],5), np.round(modele.MSE_Sigma_list[-1],5)))
    
    
    
    ax[1].plot(abscisse, modele_batch.MSE_beta_list, label = 'MSE with batch')
    ax[1].plot(abscisse, modele.MSE_beta_list, label = 'MSE without batch')
    ax[1].legend()
    ax[1].set_ybound( lower=0, upper=0.7)
    ax[1].set_title('MSE of beta. last MSE with batch :{} . last_MSE without batch : {}'.format(np.round(modele_batch.MSE_beta_list[-1],5), np.round(modele.MSE_beta_list[-1],5)))
    

    ax[2].plot(abscisse, modele_batch.ELBO_list, label = 'ELBO with batch')
    ax[2].plot(abscisse, modele.ELBO_list, label = 'ELBO without batch')
    ax[2].legend()
    ax[2].set_xscale('log')
    ax[2].set_title('ELBO')
    
    
    ax[3].plot(abscisse, np.array(modele.ELBO_list)-np.array(modele_batch.ELBO_list), label =  'ELBO without - ELBO with')
    ax[3].legend()
    ax[3].set_title('ELBO without batches - ELBO with batches')
    ax[3].axhline(y=0, c = 'red')
    ax[3].set_ybound( lower=-20, upper=20)
    plt.savefig(name)
    
    

def compare_models_nstep(modele, modele_little,big_tolerance, little_tolerance): 
    n,p = modele.Y.shape
    d = modele.beta.shape[0]
    ELBO = np.round(modele.current_ELBO,5)
    
    name = 'tolerance = {} and {},n = {}, p = {}, d = {}, precise step : last ELBO : {}, time : {}, inexact step : last ELBO : {}, time : {}.jpg'.format(big_tolerance,little_tolerance, 
                                         n,p,d,  np.round(modele.current_ELBO,1), np.round(modele.running_time,0),  np.round(modele_little.current_ELBO,1),np.round(modele_little.running_time,0))
    abscisse = np.arange(len(modele.MSE_Sigma_list))
    fig,ax = plt.subplots(4,1,figsize = (15,12))
    plt.subplots_adjust(hspace = 0.4)
    plt.suptitle(name)
    ax[0].plot(abscisse, modele_little.MSE_Sigma_list, label = 'MSE inexact step')
    ax[0].plot(abscisse, modele.MSE_Sigma_list, label = 'MSE precise step')
    ax[0].legend()
    ax[0].set_ybound( lower=0, upper=0.7)
    ax[0].set_title('MSE of Sigma. last MSE inexact step :{} . last_MSE precise step : {}'.format(np.round(modele_little.MSE_Sigma_list[-1],5),
                                                                                        np.round(modele.MSE_Sigma_list[-1],5)))
    
    
    ax[1].plot(abscisse, modele_little.MSE_beta_list, label = 'MSE inexact step')
    ax[1].plot(abscisse, modele.MSE_beta_list, label = 'MSE precise step')
    ax[1].legend()
    ax[1].set_title('MSE of beta. last MSE inexact step :{} . last_MSE precise step : {}'.format(np.round(modele_little.MSE_beta_list[-1],5), np.round(modele.MSE_beta_list[-1],5)))
    

    ax[2].plot(abscisse, modele_little.ELBO_list, label = 'ELBO inexact step')
    ax[2].plot(abscisse, modele.ELBO_list, label = 'ELBO precise step')
    ax[2].legend()
    ax[2].set_xscale('log')
    ax[2].set_title('ELBO')
    
    
    ax[3].plot(abscisse, np.array(modele.ELBO_list)-np.array(modele_little.ELBO_list), label =  'ELBO precise step - ELBO inexact step')
    ax[3].legend()
    ax[3].set_title('ELBO without batches - ELBO with batches')
    ax[3].axhline(y=0, c = 'red')
    ax[3].set_ybound( lower=-20, upper=20)
    plt.savefig(name)
    

def print_model(modele): 
    abscisse = np.arange(len(modele.MSE_Sigma_list))
    fig,ax = plt.subplots(4,1,figsize = (12,12))
    ax
    plt.subplots_adjust(hspace = 0.4)
    ax[0].plot(abscisse, modele.MSE_Sigma_list)
    Sigma_min = np.round(min(modele.MSE_Sigma_list),5)
    Sigma_argmin = np.argmin(modele.MSE_Sigma_list)
    ax[0].set_title('MSE of Sigma. last MSE :{} . best_MSE {}, argmin = {}'.format(np.round(modele.MSE_Sigma_list[-1],5), Sigma_min, Sigma_argmin))
    
    ax[1].plot(abscisse, modele.MSE_beta_list)
    beta_min = np.round(min(modele.MSE_beta_list),5)
    beta_argmin = np.argmin(modele.MSE_beta_list)
    ax[1].set_title('MSE of beta. last MSE :{} . best_MSE {}, argmin = {}'.format(np.round(modele.MSE_beta_list[-1],5), beta_min, beta_argmin))
    
    ax[2].plot(abscisse, modele.ELBO_list)
    ax[2].set_xscale('log')
    ax[2].set_title('ELBO')
    
    ax[3].plot(abscisse, modele.MSE_Sigma_list)
    ax[3].set_title('MSE of Sigma (x axis in log scale)')
    ax[3].set_xscale('log')

# %%
# Out:
# 608.3541505336761

# %% [markdown]
# sizes :
#
# $ Y : (n,p)$
#
# $O : (n,p)$
#
# $\Sigma :  (p,p)$
#
# covariates ($x$) : $(n,d)$
#
# $\beta : (d,p)$
#
# $M : (n,p)$
#
# $S : (n,p)$ . Should be seen as $(n,p,p)$ but since all the $n$  matrix $(p,p)$ are diagonal, we only need $p$ points to encode it.

# %% [markdown]
# d = 2 # nb of cavariates
# n = 200; p = 50
#
#
# Does not work very well :
#
# $MSE_{Sigma} = 1.15$ : probably stock in a local minima.
# $MSE_{beta} = 0.95$
# lr = 0.1 for both
# ***
#
# d = 5 # nb of cavariates
# n = 200; p = 50
#
# lr = 0.01 for VE step
# LR = 0.1 for M_step
# added an init for beta :
#
# MSE with Sigma :  0.10714
# MSE with beta :  0.12845
#
# result after 250 VEM step.
#
# took about 25 minutes
#
# ***
# Same as above but without inittialization for beta :
#
#  MSE with Sigma :  0.08429
#  MSE with beta :  0.12089
#
#  we can go to 0.06 and 0.11 if we go 50 step more

# %% [markdown]
# ## The Poisson lognormal (PLN) model
#
#
# - Consider $n$ sites $(i=1 \ldots n)$
#
# - Measure $x_{i}=\left(x_{i h}\right)_{1 \leq h \leq d}$ :
# $x_{i h}=$ given environmental descriptor (covariate) for site $i$
# (altitude, temperature, latitude, ...)
#
# - Consider $p$ species $(j=1 \ldots p)$ Measure $Y=\left(Y_{i j}\right)_{1 \leq i \leq n, 1 \leq j \leq p}$ :
#
# - Measure $Y = Y_{i j}=$ number of observed individuals from species $j$ in site $i$ (abundance).
#
# - Associate a random vector $Z_{i}$ with each site Assume that the unknown $\left(Z_{i}\right)_{1 \leq i \leq n}$ are iid (no spatial structure):
# $$
# Z_{i} \sim \mathcal{N}_{p}(0, \Sigma)
# $$
# - Assume that the observed abundances $\left(Y_{i j}\right)_{1 \leq i \leq n, 1 \leq j \leq p}$ are independent conditionally on the $Z=\left(Z_{i}\right)_{i}$
#
#
# $$
# \left(Y_{i j} \mid Z_{i j}\right) \sim \mathcal{P}\left(\exp \left(o_{i j}+x_{i}^{\top} \beta_{j}+Z_{i j}\right)\right)
# $$
#
#
# The parameter of the model is $\theta = (\beta, \Sigma)$.
#
# Since the model depends on latent variables, we want to apply the EM algortihm. However, EM requires to compute the following :
#
# $$
# \mathbb{E}_{\theta}\left[p_{\theta}\left(Z_{i} \mid Y\right)\right]=\mathbb{E}_{\theta}\left[p_{\theta}\left(Z_{i} \mid Y_{i}\right)\right] \propto \int_{\mathbb{R}^{p}} p_{\Sigma}\left(Z_{i}\right) \prod_{j} p_{\theta}\left(Y_{i j} \mid Z_{i j}\right) \mathrm{d} Z_{i}
# $$
#
# Which is intractable in practice.
#
# We have two alternatives here. The first one is an approximation of this integral via MCMC methods. The second one is the variationnal approach. We adopt here the second approach.
#
# The goal of variationnal approach is to approximate $p_{\theta}(Z \mid Y)$ with some law $q^{\star}(Z)$ from which we can compute the expectation with respect to $\theta$.
#
#
# We find such a law by maximizing the Evidence Lower BOund (ELBO), that is :
# $$
# q^{\star} = \underset{q \in \mathcal{Q}}{\operatorname{argmax}} J_{\theta,q}(Y)
# $$
# <br>
# $$
# \begin{align} J_{\theta, q}(Y)& =\log p_{\theta}(Y)-K L\left[q(Z) \| p_{\theta}(Z \mid Y)\right]                                    \\
#                               & = \mathbb{E}_{q}\left[\log p_{\theta}(Y, Z)\right] \underbrace{-\mathbb{E}_{q}[\log q(Z)]}_{\text {entropy } \mathcal{H}(q)}    \end{align}
# $$
#
#
# Where $\mathcal{Q}$ is a set of distributions.
# The Variational EM (VEM) consists in alternate between two steps :
# - VE step: update $q$
# $$
# q^{h+1}=\underset{q \in \mathcal{Q}}{\arg \max } J_{\theta^{h}, q}(Y)=\underset{q \in \mathcal{Q}}{\arg \min } K L\left[q(Z) \| p_{\theta^{h}}(Z \mid Y)\right]
# $$
# - M step: update $\theta$
# $$
# \theta^{h+1}=\underset{\theta}{\arg \max } J_{\theta, q^{h+1}}(Y)=\underset{\theta}{\arg \max } \mathbb{E}_{q^{h+1}}\left[\log p_{\theta}(Y, Z)\right]
# $$

# %% [markdown]
# # VEM for PLN
#
# We consider
# $$
# \mathcal{Q}_{\text {Gauss }}=\{q: q=\mathcal{N}(m, S)\}
# $$
#
# The parameters $M = (m_i)_{1\leq i \leq n} \in \mathbb{R}^{n\times p}$  and $ S = (S_i)_{1\leq i \leq n} \in \mathbb{R}^{n\times p} $ are called variational parameters whereas $\theta = (\beta,\Sigma)$ is called model parameter.
#
# The ELBO can be computed as :
#
#
# <br>
# <br>
#
#
# $$
# \begin{aligned}
# J_{\theta, q}(Y)=& \sum_{i} \mathbb{E}_{q_{i}}\left[\log p_{\theta}\left(Z_{i}\right)\right]+\sum_{i} \mathbb{E}_{q_{i}}\left[\log p_{\theta}\left(Y_{i} \mid Z_{i}\right)\right]+\sum_{i} \mathcal{H}\left[\mathcal{N}\left(m_{i}, S_{i}\right)\right] \\
# =&-\frac{n}{2} \log |\Sigma|-\frac{1}{2} \sum_{i} \mathbb{E}_{\mathcal{N}\left(\cdot m_{i}, S_{i}\right)}\left[Z_{i}^{\top} \Sigma^{-1} Z_{i}\right] \\
# &+\sum_{i, j} \mathbb{E}_{\mathcal{N}\left(\cdot ; m_{i}, S_{i}\right)}\left[-\exp \left(o_{i j}+x_{i}^{\top} \beta_{j}+Z_{i j}\right)+Y_{i j}\left(o_{i j}+x_{i}^{\top} \beta_{j}+Z_{i j}\right)\right] \\
# &+\frac{1}{2} \sum_{i} \log \left|S_{i}\right|+\mathrm{cst}
# \end{aligned}
# $$
# We can evaluate some moments of $Z$ :
# $$
# \begin{aligned}
# \mathbb{E}_{\mathcal{N}\left(\cdot ; m_{i}, s_{i}\right)}\left(Z_{i}\right) &=m_{i}, & \mathbb{E}_{\mathcal{N}\left(\cdot ; m_{i}, S_{i}\right)}\left(Z_{i}^{\top} \Sigma^{-1} Z_{i}\right)=m_{i}^{\top} \Sigma^{-1} m_{i}+\operatorname{tr}\left(\Sigma^{-1} S_{i}\right) \\
# \mathbb{E}_{\mathcal{N}\left(\cdot ; m_{i}, S_{i}\right)}\left(e^{Z_{i j}}\right) &=\exp \left(m_{i j}+\left[S_{i}\right]_{j j}^{2} / 2\right) &
# \end{aligned}
# $$
#
# We then get :
#
# $$
# \begin{aligned}
# J_{\theta, q}(y) &=-\frac{n}{2} \log |\Sigma|-\frac{1}{2} \sum_{i} m_{i}^{\top} \Sigma^{-1} m_{i}+tr\left(\Sigma^{-1} S_{i}\right) \\
# &+\sum_{i, j}-\exp \left(o_{i j}+x_{i}^{T} \beta_{j}+m_{i j}+\left[S_{i}\right]_{j j}^{2} / 2\right)+Y_{i j}\left(o_{i j}+x_{i}^{T} \beta_{j}+m_{i j}\right) \\
# &+\frac{1}{2} \sum_{i} \log \left|S_{i}\right|+c s t .
# \end{aligned}
# $$
#
#
# % the problem is convex if the S_i are diagonals. %
#
# We have a closed form for the $\Sigma$ step, that is :
#
# $$
# \widehat{\Sigma}=\frac{1}{n} \sum_{i}\left(m_{i} m_{i}^{\top}+S_{i}\right)
# $$
#
# For $\beta$, we have the following :
#
#
#
# $$
# \nabla _{\beta}=-X^{\top} \exp \left(0+M+\frac{S \odot S}{2}+X \beta\right)+\frac{1}{2} X^{\top} Y
# $$
#
# However, we don't have any closed form for the VE step.
#
# We consider now $S$ as $(n,p)$ matrix. Indeed, the $S_i$ are supposed diagonal matrices so we only need $p$ points to encode each of them. Considering $S$ this way is simpler for calculus. Here are the gradients with respect to the variational parameters.
#
# $$
# \nabla_{M} J=-M \Sigma^{-1}-\exp \left(O+x \beta+M+\frac{S \odot S}{2}\right)+Y
# $$
#
# $$
# \nabla_{S} J=-\frac{1}{2}\mathbb{1}_{n}\mathbb{1}_{p}^{T} D_{\Sigma^{-1}}-S\odot  \exp \left(0+X \beta+M+\frac{S \odot  S}{2}\right)+\frac{1}{2} \frac{1}{S}
# $$
#
#
# We denote $D_{\Sigma^{-1}}$ the diagonal matrix composed of the diagonal of $\Sigma^{-1}$. The exponential is applied component-wise, as well as the division $\frac 1 S$.

# %%
print('beta of the model : \n', model.beta)
print('true_beta : \n', true_beta)
print('\n \n \n')
print('Sigma of the model : \n', model.Sigma)
print('true_Sigma : \n', true_Sigma)
# Out:
# beta of the model :
#  tensor([[ 1.3317,  1.1693, -0.7714, -0.3931,  0.0435,  0.0249,  1.1270],
#         [ 0.2621, -2.2377, -0.7254, -1.3219, -0.3614, -0.8606,  0.7364],
#         [ 0.9908,  1.3611,  0.3054, -0.1442, -0.6935, -0.0047, -0.5331],
#         [-0.4578,  2.0091, -0.9855,  1.7188,  0.3636, -0.1286, -1.5100],
#         [-0.6545, -0.9745,  0.9794,  0.1433, -0.9164, -0.8507, -0.3245]],
#        requires_grad=True)
# true_beta :
#  tensor([[ 1.5286,  1.3868, -0.4622, -1.1306, -0.5680, -0.1138,  0.9410],
#         [ 0.8277, -2.0033, -0.6267, -0.7433,  0.4777, -0.7171,  1.0790],
#         [ 0.9449,  0.9672,  0.1545, -0.5985, -1.0944, -0.1459, -0.8818],
#         [-0.9332,  1.6057, -1.2102,  1.4245,  0.0943,  0.4571, -0.8471],
#         [-1.0952, -0.6439,  0.9200,  0.4530, -0.6434, -1.6909, -0.6297]])
#
#
#
#
# Sigma of the model :
#  tensor([[ 1.5357,  1.1168,  0.8311,  0.3202,  0.0990, -0.2129, -0.0918],
#         [ 1.1168,  1.6791,  1.1148,  0.6198,  0.4701,  0.0762,  0.2010],
#         [ 0.8311,  1.1148,  1.6331,  0.8035,  0.7252,  0.4067,  0.4625],
#         [ 0.3202,  0.6198,  0.8035,  1.2297,  0.9507,  0.7453,  0.7099],
#         [ 0.0990,  0.4701,  0.7252,  0.9507,  1.8501,  1.2266,  1.1051],
#         [-0.2129,  0.0762,  0.4067,  0.7453,  1.2266,  1.6672,  1.0487],
#         [-0.0918,  0.2010,  0.4625,  0.7099,  1.1051,  1.0487,  1.4284]])
# true_Sigma :
#  tensor([[1.0000, 0.5000, 0.2500, 0.1250, 0.0625, 0.0312, 0.0156],
#         [0.5000, 1.0000, 0.5000, 0.2500, 0.1250, 0.0625, 0.0312],
#         [0.2500, 0.5000, 1.0000, 0.5000, 0.2500, 0.1250, 0.0625],
#         [0.1250, 0.2500, 0.5000, 1.0000, 0.5000, 0.2500, 0.1250],
#         [0.0625, 0.1250, 0.2500, 0.5000, 1.0000, 0.5000, 0.2500],
#         [0.0312, 0.0625, 0.1250, 0.2500, 0.5000, 1.0000, 0.5000],
#         [0.0156, 0.0312, 0.0625, 0.1250, 0.2500, 0.5000, 1.0000]])

# %%
    
    
save_model(model, batch_size = None, time =  '7min38s')
