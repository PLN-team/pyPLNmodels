# %%
# %load_ext autoreload

# %autoreload 2

# %%
from fastPLNmodels.utils import MSE,Poisson_reg, sample_PLN, sigmoid 
from fastPLNmodels.utils import logit, log_stirling, build_block_Sigma
from fastPLNmodels.utils import init_Sigma
import matplotlib.pyplot as plt
from pandas import read_csv
import math 
import time 
import pandas as pd 
plt.style.use('ggplot')

import threading
from tqdm import tqdm
import numpy as np
import seaborn as sns 
import torch
import scipy.linalg as SLA 
from scipy.linalg import toeplitz 
from sklearn.linear_model import LinearRegression
torch.set_default_dtype(torch.float64)

# %%
torch.set_default_dtype(torch.float64)

# %%
#get the device. can be used with GPU
if torch.cuda.is_available(): 
    device = torch.device('cuda') 
else : 
    device = torch.device('cpu')
print('device : ', device)
# Out:
# device :  cpu

# %%
def show(model,name_doss = '' , save = False):
    '''
    function to show one model. It will plot the MSE of Sigma and beta according to the true parameters and 
    the log_likelihood in the y axis with the runtime in the x-axis.Will also plot the norm of the gradients and 
    the variance of the weights used for the importance sampling. 
    
    args : 
        'model' MC_PLNPCA object where you have called model.fit_IMPS()
        'name_doss' : str. the name of the file you want to save the graphic. 
        'save' : bool. If True, the graphic will be saved. If false, won't be saved. 
        
    returns : 
            None but displays the figure. It can also save the figure if save = True. 
    '''
    fig,ax = plt.subplots(4,1,figsize = (15,15))
    
    max_ = np.max(np.array(model.ELBO_list))
    print('max ', max_)
    #MSE of Sigma
    abscisse = model.running_times
    plt.subplots_adjust(hspace = 0.4)
    ax[0].plot(abscisse, model.MSE_Sigma_list)
    ax[0].set_title(r'MSE $(\Sigma- \hat \Sigma)$')
    ax[0].set_xlabel('Seconds')
    ax[0].set_ylim(ymin= 1e-4)
    ax[0].set_ylabel('(a)')
    ax[0].set_yscale('log')
    
    #MSE of beta. 
    ax[1].plot(abscisse, model.MSE_beta_list)
    ax[1].set_title(r'MSE $(\beta - \hat \beta)$') 
    ax[1].set_yscale('log')
    ax[1].set_ylim(ymin= 1e-4)
    ax[1].set_ylabel('(b)')
    ax[1].legend()
    
    ax[2].plot(abscisse, model.MSE_B_zero_list)
    ax[2].set_title(r'MSE $(B^{0} - \hat {B^{0}})$') 
    ax[2].set_yscale('log')
    ax[2].set_ylim(ymin= 1e-4)
    ax[2].set_ylabel('(b)')
    ax[2].legend()
    
    #log likelihood of the model. will also plot the log likelihood of the model with the true parameters. 
    length = int(len(abscisse)*0.2)
    ax[3].plot(abscisse[length:], np.array(model.ELBO_list)[length:])#-max_)
    ax[3].set_title('ELBO')
    ax[3].set_ylabel('ELBO')
    ax[3].set_xlabel('Seconds')
    #variational_log_like = variational_model.compute_mean_log_likelihood(0.0001)[0].item()
    #ax[2].axhline(variational_log_like, c = 'black', label = 'variaitional likelihood')
    #ax[3].set_yscale('symlog')
    ax[3].set_ylabel('(c)')
    ax[3].legend()

    if save : 
        plt.savefig(name_doss)
    plt.show()
    
# show(model_blockwise)

# %%
def init_B_zero(Y, covariates): 
    logistic_Y = (Y==0)
    B_zero_init = fit(logistic_Y)
    return B_zero_init

# %%
def trunc_log(x,eps = 1e-16):
    y = torch.min(torch.max(x,torch.tensor([eps])), torch.tensor([1-eps]))
    return torch.log(y)

# %%
class ZI_PLN():
    def __init__(self, class_optimizer = torch.optim.Rprop, true_value = False): 
        '''
            Initialization. We only define some useful stuff. The intialization of the
            parameters is done int the init_data() function. 
        '''
        self.old_loss = 1
        
        self.class_optimizer = class_optimizer
        
        self.true_value = true_value
        # some lists to store some stats
        self.t0 = time.time()
        self.MSE_Sigma_list = list()
        self.MSE_beta_list = list()
        self.MSE_B_zero_list = list()
        self.ELBO_list = list()
        self.running_times = list()
        self.cmpt = 0 
        
    def init_data(self,data, good_init = False ): 
        '''
        function to extract the data. This function is just here to have a code more compact. We 
        also intialize the parameters.
        
        args : 
              'data': list with 3 elements : Y, O and covariates in this order. 
        '''
        #known variables
        self.Y = data[0].to(device);self.O = data[1].to(device);self.covariates = data[2].to(device)
        self.n, self.p = self.Y.shape
        self.d = self.covariates.shape[1]

        #model parameter 
        noise = torch.randn(self.p)
        
        
        if good_init : 
            poiss_reg = Poisson_reg()
            poiss_reg.fit(self.Y, self.O,self.covariates)
            self.beta = torch.clone(poiss_reg.beta.detach()).to(device)
            self.Sigma =  init_Sigma(self.Y, self.O, self.covariates, self.beta).to(device) 
            self.B_zero = (init_B_zero(self.Y, self.covariates)).to(device) #torch.randn((self.d,self.p)).to(device)
            self.C = torch.cholesky(self.Sigma).to(device)
            self.M = self.init_M(300,0.1).to(device)
        
        else : 
            self.beta = torch.zeros(self.d, self.p)
            self.Sigma =  (torch.diag(noise**2)+ 1e-1).to(device) 
            self.B_zero = torch.zeros(self.d, self.p)
            self.M = torch.zeros(self.n, self.p).to(device)

        self.beta.requires_grad_(False)
        
        self.Sigma.requires_grad_(False)#we won't use gradients on Sigma

        if self.true_value : 
            self.beta = torch.clone(true_beta)
            self.Sigma = torch.clone(true_Sigma)
            self.B_zero = torch.clone(true_B_zero)
        self.B_zero.requires_grad_(True)
        
        self.dirac = (self.Y==0)
        #variational parameter
        self.M.requires_grad_(True)
        self.S = torch.randn((self.n,self.p)).to(device)
        self.S.requires_grad_(True)
        self.pi = torch.empty(self.n, self.p).uniform_(0, 1).to(device)*self.dirac
        self.pi.requires_grad_(False)
        
        self.params = {'S' : self.S,'M': self.M, 'beta' : self.beta, 
                       'Sigma' : self.Sigma,'pi': self.pi, 
                       'B_zero': self.B_zero}
        
    def compute_ELBO_ZI(self): 
        return ELBO_ZI(self.Y,self.O,self.covariates, self.M, self.S, self.Sigma, self.beta, self.pi, self.B_zero, self.dirac)
    def ZI_grad_M(self): 
        A = torch.exp(self.O+self.M+torch.multiply(self.S,self.S)/2)
        return  torch.multiply(1-self.pi, self.Y-A)-torch.mm((self.M-torch.mm(self.covariates, self.beta)), torch.inverse(self.Sigma))
    def ZI_grad_S(self): 
        A = torch.exp(self.O+self.M+torch.multiply(self.S,self.S)/2)
        first = torch.div(1,self.S)
        sec = torch.multiply(torch.multiply(1-self.pi, self.S), A)
        third = torch.mm(self.S,torch.diag(torch.diag(torch.inverse(self.Sigma))))
        return first - sec - third
    
    def ZI_grad_B_zero(self):
        first =  torch.mm(self.covariates.T, self.pi)
        XB_zero = torch.mm(self.covariates, self.B_zero)
        sec = torch.mm(self.covariates.T, sigmoid(XB_zero))
        return first - sec
    
    def ZI_grad_pi(self,pi_): 
        A = torch.exp(self.O+self.M+torch.multiply(self.S,self.S)/2)
        XB_zero = torch.mm(self.covariates, self.B_zero)
        return (A + XB_zero -logit(pi_))*self.dirac
    
    def fit(self,Y, O, covariates, tolerance ,Niter,lr,  verbose, good_init): 
        '''
        gradient ascent function. We compute the gradients thanks to the autodifferentiation of pytorch. 

        args : 
                'optimizer' : torch.optim.optimizer. the optimizer for the parameters. 

                'compute_gain' : function. It should call the parameters by itself. i.e. we will
                                call compute_gain() without any parameter in argument. 

                       
                'tolerance': float. the threshold we set to stop the algorithm. It will 
                              stop  if we are not improving the loss more than tolerance. 
                              
                'N_epoch': int. the Maximum number of epoch we are ready to do. 
                

                'Verbose' : bool. if True, will print some messages useful to 
                            interpret the gradient ascent. If False, nothing will be printed. 
 
        returns : None 
        '''
        data = [Y,O,covariates]
        self.init_data(data)
        
        optimizer = self.class_optimizer([self.S,self.M, self.B_zero], lr = lr)
        
        optimizer.zero_grad()

        stop_condition = False 
        i = 0

        while i < Niter and stop_condition == False: 
            #with torch.no_grad(): 
            for j in range(50): 
                optimizer.zero_grad()
                loss = -self.compute_ELBO_ZI()
                loss.backward()
                optimizer.step()
                delta = self.old_loss - loss.item()
            self.ELBO_list.append(-loss.item())
            # condition to see if we have reach the tolerance threshold
            if  abs(delta) < tolerance :
                stop_condition = True 
            
            self.old_loss = loss.item()
            
            with torch.no_grad(): 
                self.Sigma = closed_Sigma(self.M,self.S,self.covariates,self.beta)
                self.beta = closed_beta(self.covariates,self.M)
                self.pi = closed_pi(self.O,self.M,self.S,self.dirac, self.covariates, self.B_zero)
                

            # keep track of the error with Sigma. 
            
            self.MSE_Sigma_list.append(torch.mean((self.Sigma-true_Sigma)**2).item())
            self.MSE_beta_list.append(torch.mean((self.beta-true_beta)**2).item())
            self.MSE_B_zero_list.append(torch.mean((self.B_zero-true_B_zero)**2).item())
            
            
            print(' MSE with Sigma : ', np.round(self.MSE_Sigma_list[-1],5))
            print(' MSE with beta : ', np.round(self.MSE_beta_list[-1],5))
            print('MSE with B_zero', np.round(self.MSE_B_zero_list[-1],5))
            print('ELBO', -loss.item())
            i += 1
            #keep track of the time 
            self.running_times.append(time.time()-self.t0)

        # print some stats if we want to 
        if verbose : 
            if stop_condition : 
                print('---------------------------------Tolerance {} reached in {} iterations'.format(tolerance, i))
            else : 
                print('---------------------------------Maximum number of iterations reached : ', N_epoch, 'last delta = ', delta)

    def fit_VEM(self,Y, O, covariates, tolerance ,Niter,nb_each_iter, lr,  verbose): 
        self.t0 = time.time()
        data = [Y,O,covariates]
        self.init_data(data)

        for i in range(Niter): 
            self.VE_step(nb_each_iter, 0, 10*lr)
            self.M_step(nb_each_iter, 0, lr)
            closed_pi(self.O,self.M,self.S,self.dirac, self.covariates, self.B_zero)
    def fit_blockwise(self,Y, O, covariates, tolerance ,Niter,nb_each_iter, lr,  verbose): 
        self.t0 = time.time()
        data = [Y,O,covariates]
        self.init_data(data)
        for i in tqdm(range(Niter)): 
            ## VE step 
            self.update_param(self.M, nb_each_iter, lr)
            self.update_param(self.S, nb_each_iter, lr)
                
            with torch.no_grad(): 
                    self.pi = closed_pi(self.O,self.M,self.S,self.dirac, self.covariates, self.B_zero)
                    self.keep_records()

            #M step
            self.update_param(self.B_zero, nb_each_iter, lr)
            
            with torch.no_grad(): 
                self.beta = closed_beta(self.covariates,self.M)
                self.Sigma = closed_Sigma(self.M,self.S,self.covariates,self.beta)#= closed_pi(self.O,self.M,self.S,self.dirac, self.covariates, self.B_zero)
                self.keep_records()
            print('ELBO :', -self.loss)



    def update_param(self, param, nb_iter, lr): 
        param_optimizer = self.class_optimizer([param], lr = lr)
        param_optimizer.zero_grad()
        for i in range(nb_iter): 
            self.loss = -self.compute_ELBO_ZI()
            self.loss.backward()
            param_optimizer.step()
            param_optimizer.zero_grad()
            self.keep_records()
        return 
            
    def VE_step(self, N_iter_max,tolerance, lr): 
        VE_optimizer = self.class_optimizer([self.M,self.S], lr  = lr)
        VE_optimizer.zero_grad()
        with torch.no_grad():
            self.pi = closed_pi(self.O,self.M,self.S,self.dirac, self.covariates, self.B_zero)
        crit = 2*tolerance +1
        i = 0
        self.old_M = torch.clone(self.M)
        self.old_S = torch.clone(self.S)
        while i < N_iter_max and crit > tolerance : 
            loss = -self.compute_ELBO_ZI()
            loss.backward()
            VE_optimizer.step()
            VE_optimizer.zero_grad()
            i += 1
            crit = torch.max((torch.norm(self.M-self.old_M))/torch.norm(self.old_M), torch.norm(self.S-self.old_S)/torch.norm(self.old_S))
#             print('ELBO', -loss.item())
#             print('crit :', crit)
            self.old_M = torch.clone(self.M)
            self.old_S = torch.clone(self.S)
            self.MSE_Sigma_list.append(torch.mean((self.Sigma-true_Sigma)**2).item())
            self.MSE_beta_list.append(torch.mean((self.beta-true_beta)**2).item())
            self.MSE_B_zero_list.append(torch.mean((self.B_zero-true_B_zero)**2).item())
            self.ELBO_list.append(-loss.item())
            self.running_times.append(time.time()-self.t0)

            
    def keep_records(self):
        self.MSE_Sigma_list.append(torch.mean((self.Sigma-true_Sigma)**2).item())
        self.MSE_beta_list.append(torch.mean((self.beta-true_beta)**2).item())
        self.MSE_B_zero_list.append(torch.mean((self.B_zero-true_B_zero)**2).item())
        self.ELBO_list.append(-self.loss.item())
        self.running_times.append(time.time()-self.t0)

    def M_step(self, N_iter_max,tolerance, lr): 
        M_optimizer = self.class_optimizer([self.B_zero], lr  = lr)
        M_optimizer.zero_grad()
        with torch.no_grad():
            #pass 
            self.beta = closed_beta(self.covariates,self.M)
            self.Sigma = closed_Sigma(self.M,self.S,self.covariates,self.beta)#= closed_pi(self.O,self.M,self.S,self.dirac, self.covariates, self.B_zero)
        crit = 2*tolerance+1 
        i = 0
        self.old_B_zero = torch.clone(self.B_zero)
        while i < N_iter_max and crit > tolerance : 
            loss = -self.compute_ELBO_ZI()
            loss.backward()
            M_optimizer.step()
            M_optimizer.zero_grad()
            i += 1
            crit = (torch.norm(self.B_zero-self.old_B_zero))/torch.norm(self.old_B_zero)
            self.MSE_Sigma_list.append(torch.mean((self.Sigma-true_Sigma)**2).item())
            self.MSE_beta_list.append(torch.mean((self.beta-true_beta)**2).item())
            self.MSE_B_zero_list.append(torch.mean((self.B_zero-true_B_zero)**2).item())
            self.ELBO_list.append(-loss.item())
            self.running_times.append(time.time()-self.t0)
            #             print('crit :', crit)
            self.old_B_zero = torch.clone(self.B_zero)
        print(' MSE with Sigma : ', np.round(MSE(self.Sigma-true_Sigma),5))
        print(' MSE with beta : ', np.round(MSE(self.beta - true_beta),5))
        print('MSE with B_zero', np.round(MSE(self.B_zero -true_B_zero ).item(),5))
        print('ELBO :', -self.loss.item())

    def init_M(self, N_iter, lr, eps = 7e-3):
        def batch_un_log_posterior(W): 
            return batch_log_P_WgivenY(self.Y, self.covariates, self.O, W, self.C, self.beta) 
        self.batch_un_log_posterior = batch_un_log_posterior
        W = torch.randn(self.n,self.p)
        W.requires_grad_(True)
        optimizer = torch.optim.Rprop([W], lr = lr)
        criterion = 2*eps
        old_W = torch.clone(W)
        keep_condition = True
        for i in tqdm(range(N_iter)):#  i < N_iter and keep_condition: 

            loss = -torch.mean(self.batch_un_log_posterior(W))
            loss.backward()
            optimizer.step()
            crit = torch.max(torch.abs(W-old_W))
            optimizer.zero_grad()
            if crit<eps and i > 2 : 
                keep_condition = False 
            old_W = torch.clone(W)
        print('nb iteration : ', i)
        return W

# %%
model = ZI_PLN()
model.fit(Y_sampled, O, covariates, tolerance=0 ,Niter = 50,lr = 0.1,  verbose= False, good_init = False)
# Out:
#  MSE with Sigma :  0.10238
#  MSE with beta :  0.65776
# MSE with B_zero 0.67957
# ELBO 921318.1088026465
#  MSE with Sigma :  0.11119
#  MSE with beta :  0.47938
# MSE with B_zero 0.59194
# ELBO 1025329.4866282748
#  MSE with Sigma :  0.13599
#  MSE with beta :  0.42082
# MSE with B_zero 0.4263
# ELBO 1037845.4326773109
#  MSE with Sigma :  0.18425
#  MSE with beta :  0.3934
# MSE with B_zero 0.37917
# ELBO 1043823.3656850067
#  MSE with Sigma :  0.2423
#  MSE with beta :  0.37204
# MSE with B_zero 0.33694
# ELBO 1048639.065478163
#  MSE with Sigma :  0.33576
#  MSE with beta :  0.35236
# MSE with B_zero 0.3207
# ELBO 1052474.3574132316
#  MSE with Sigma :  0.48435
#  MSE with beta :  0.33629
# MSE with B_zero 0.30241
# ELBO 1054669.6354440574
#  MSE with Sigma :  0.54604
#  MSE with beta :  0.32267
# MSE with B_zero 0.29869
# ELBO 1055738.8101000758
#  MSE with Sigma :  0.58156
#  MSE with beta :  0.31112
# MSE with B_zero 0.29496
# ELBO 1056613.6357332752
#  MSE with Sigma :  0.6249
#  MSE with beta :  0.30157
# MSE with B_zero 0.2977
# ELBO 1057442.32368176
#  MSE with Sigma :  0.66299
#  MSE with beta :  0.29354
# MSE with B_zero 0.30234
# ELBO 1058264.4743563638
#  MSE with Sigma :  0.67168
#  MSE with beta :  0.28582
# MSE with B_zero 0.30748
# ELBO 1059033.5314886793
#  MSE with Sigma :  0.66348
#  MSE with beta :  0.27789
# MSE with B_zero 0.31516
# ELBO 1059665.8811498757
#  MSE with Sigma :  0.64714
#  MSE with beta :  0.27022
# MSE with B_zero 0.32107
# ELBO 1060203.8934825521
#  MSE with Sigma :  0.62499
#  MSE with beta :  0.26284
# MSE with B_zero 0.32912
# ELBO 1060647.5833015167
#  MSE with Sigma :  0.57843
#  MSE with beta :  0.25598
# MSE with B_zero 0.33656
# ELBO 1061022.528680627
#  MSE with Sigma :  0.5386
#  MSE with beta :  0.24992
# MSE with B_zero 0.34316
# ELBO 1061345.1842097577
#  MSE with Sigma :  0.49819
#  MSE with beta :  0.24429
# MSE with B_zero 0.34777
# ELBO 1061628.9722827896
#  MSE with Sigma :  0.46241
#  MSE with beta :  0.23907
# MSE with B_zero 0.35155
# ELBO 1061881.1464640945
#  MSE with Sigma :  0.42664
#  MSE with beta :  0.23428
# MSE with B_zero 0.35442
# ELBO 1062110.0397380407
#  MSE with Sigma :  0.40263
#  MSE with beta :  0.22987
# MSE with B_zero 0.35704
# ELBO 1062317.919207389
#  MSE with Sigma :  0.37907
#  MSE with beta :  0.22578
# MSE with B_zero 0.35943
# ELBO 1062507.4700642484
#  MSE with Sigma :  0.35932
#  MSE with beta :  0.2219
# MSE with B_zero 0.36144
# ELBO 1062682.725574215
#  MSE with Sigma :  0.34275
#  MSE with beta :  0.21819
# MSE with B_zero 0.36319
# ELBO 1062844.386144619
#  MSE with Sigma :  0.32877
#  MSE with beta :  0.21463
# MSE with B_zero 0.3647
# ELBO 1062993.1123748603
#  MSE with Sigma :  0.31628
#  MSE with beta :  0.21127
# MSE with B_zero 0.36618
# ELBO 1063129.038561664
#  MSE with Sigma :  0.305
#  MSE with beta :  0.20803
# MSE with B_zero 0.36754
# ELBO 1063253.7396261198
#  MSE with Sigma :  0.29459
#  MSE with beta :  0.20488
# MSE with B_zero 0.3688
# ELBO 1063367.8235340791
#  MSE with Sigma :  0.28506
#  MSE with beta :  0.20188
# MSE with B_zero 0.36974
# ELBO 1063471.8625822284
#  MSE with Sigma :  0.27632
#  MSE with beta :  0.19902
# MSE with B_zero 0.37051
# ELBO 1063566.8696509846
#  MSE with Sigma :  0.26842
#  MSE with beta :  0.19632
# MSE with B_zero 0.37106
# ELBO 1063654.074084041
#  MSE with Sigma :  0.26119
#  MSE with beta :  0.19376
# MSE with B_zero 0.3715
# ELBO 1063734.086883214
#  MSE with Sigma :  0.25464
#  MSE with beta :  0.19134
# MSE with B_zero 0.3718
# ELBO 1063807.3847717198
#  MSE with Sigma :  0.24883
#  MSE with beta :  0.18906
# MSE with B_zero 0.37204
# ELBO 1063874.736933742
#  MSE with Sigma :  0.24364
#  MSE with beta :  0.18692
# MSE with B_zero 0.37215
# ELBO 1063936.6033423108
#  MSE with Sigma :  0.23915
#  MSE with beta :  0.18491
# MSE with B_zero 0.37229
# ELBO 1063993.1365130062
#  MSE with Sigma :  0.23519
#  MSE with beta :  0.18303
# MSE with B_zero 0.37243
# ELBO 1064044.6837815996
#  MSE with Sigma :  0.23181
#  MSE with beta :  0.18127
# MSE with B_zero 0.37264
# ELBO 1064091.853460657
#  MSE with Sigma :  0.22895
#  MSE with beta :  0.17963
# MSE with B_zero 0.37291
# ELBO 1064135.0289448984
#  MSE with Sigma :  0.22648
#  MSE with beta :  0.17814
# MSE with B_zero 0.37327
# ELBO 1064174.651596015
#  MSE with Sigma :  0.22429
#  MSE with beta :  0.17673
# MSE with B_zero 0.37362
# ELBO 1064211.2553147662
#  MSE with Sigma :  0.22249
#  MSE with beta :  0.17546
# MSE with B_zero 0.37395
# ELBO 1064245.2183339463
#  MSE with Sigma :  0.22092
#  MSE with beta :  0.17429
# MSE with B_zero 0.3743
# ELBO 1064276.694828054
#  MSE with Sigma :  0.21958
#  MSE with beta :  0.17322
# MSE with B_zero 0.37465
# ELBO 1064306.0055827245
#  MSE with Sigma :  0.21841
#  MSE with beta :  0.17222
# MSE with B_zero 0.375
# ELBO 1064333.5317368384
#  MSE with Sigma :  0.21745
#  MSE with beta :  0.17131
# MSE with B_zero 0.37536
# ELBO 1064359.5119058662
#  MSE with Sigma :  0.21664
#  MSE with beta :  0.17047
# MSE with B_zero 0.37583
# ELBO 1064384.0380382387
#  MSE with Sigma :  0.21602
#  MSE with beta :  0.16969
# MSE with B_zero 0.37643
# ELBO 1064407.2419687845
#  MSE with Sigma :  0.21552
#  MSE with beta :  0.16897
# MSE with B_zero 0.37716
# ELBO 1064429.1323023185
#  MSE with Sigma :  0.21511
#  MSE with beta :  0.1683
# MSE with B_zero 0.37789
# ELBO 1064449.8322144658

# %%
Y_sampled = torch.tensor(pd.read_csv("Y").values)
O = torch.tensor(pd.read_csv("O").values)
covariates = torch.tensor(pd.read_csv("covariates").values)
true_beta = torch.tensor(pd.read_csv("true_beta").values)
true_Sigma = torch.tensor(pd.read_csv("true_Sigma").values)
true_B_zero = torch.tensor(pd.read_csv("true_B_zero").values)

model_blockwise = ZI_PLN(true_value = False, class_optimizer = torch.optim.Rprop)
model_blockwise.fit_blockwise(Y_sampled, O, covariates, tolerance = 0 ,Niter = 50,nb_each_iter= 75, lr = 0.05,  verbose = False)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-132-3d692527c6aa> in <module>
#       7
#       8 model_blockwise = ZI_PLN(true_value = False, class_optimizer = torch.optim.Rprop)
# ----> 9 model_blockwise.fit_blockwise(Y_sampled, O, covariates, tolerance = 0 ,Niter = 50,nb_each_iter= 75, lr = 0.05,  verbose = False)
#
# <ipython-input-131-b1f02610bd29> in fit_blockwise(self, Y, O, covariates, tolerance, Niter, nb_each_iter, lr, verbose)
#     179         self.t0 = time.time()
#     180         data = [Y,O,covariates]
# --> 181         self.init_data(data)
#     182         for i in tqdm(range(Niter)):
#     183             ## VE step
#
# <ipython-input-131-b1f02610bd29> in init_data(self, data)
#      36
#      37         poiss_reg = Poisson_reg()
# ---> 38         poiss_reg.fit(self.Y, self.O,self.covariates)
#      39         self.beta = torch.clone(poiss_reg.beta.detach()).to(device)
#      40         #self.beta = torch.zeros(self.d, self.p)
#
# ~/Documents/PLNpy/fastPLNmodels/utils.py in fit(self, Y, O, covariates, Niter_max, tol, lr, verbose)
#      74         grad_norm = 2*tol  # Criterion
#      75         while i<Niter_max and  grad_norm > tol :
# ---> 76             loss = -compute_l(Y, O, covariates, beta)
#      77             loss.backward()
#      78             optimizer.step()
#
# ~/Documents/PLNpy/fastPLNmodels/utils.py in compute_l(Y, O, covariates, beta)
#     145     XB = torch.matmul(covariates.unsqueeze(1), beta.unsqueeze(0)).squeeze()
#     146     # Returns the formula of the log likelihood of a poisson regression model.
# --> 147     return torch.sum(-torch.exp(O + XB)+torch.multiply(Y,O+XB))
#     148
#     149
#
# RuntimeError: The size of tensor a (200) must match the size of tensor b (20) at non-singleton dimension 1

# %%
'''
Y_sampled = torch.tensor(pd.read_csv("Y").values)
O = torch.tensor(pd.read_csv("O").values)
covariates = torch.tensor(pd.read_csv("covariates").values)

M_ = torch.tensor(pd.read_csv("M").values)
S_ = torch.tensor(pd.read_csv("S").values)
pi_ = torch.tensor(pd.read_csv("pi").values)

true_beta = torch.tensor(pd.read_csv("true_beta").values)
true_Sigma = torch.tensor(pd.read_csv("true_Sigma").values)
true_B_zero = torch.tensor(pd.read_csv("true_B_zero").values)

dirac_ = (Y_sampled==0)

ELBO_ZI(Y_sampled,O,covariates, M_, S_, true_Sigma, true_beta, pi_, true_B_zero, dirac_)
'''
# Out:
# '\nY_sampled = torch.tensor(pd.read_csv("Y").values)\nO = torch.tensor(pd.read_csv("O").values)\ncovariates = torch.tensor(pd.read_csv("covariates").values)\n\nM_ = torch.tensor(pd.read_csv("M").values)\nS_ = torch.tensor(pd.read_csv("S").values)\npi_ = torch.tensor(pd.read_csv("pi").values)\n\ntrue_beta = torch.tensor(pd.read_csv("true_beta").values)\ntrue_Sigma = torch.tensor(pd.read_csv("true_Sigma").values)\ntrue_B_zero = torch.tensor(pd.read_csv("true_B_zero").values)\n\ndirac_ = (Y_sampled==0)\n\nELBO_ZI(Y_sampled,O,covariates, M_, S_, true_Sigma, true_beta, pi_, true_B_zero, dirac_)\n'

# %%
def ELBO_ZI(Y,O,covariates, M, S, Sigma, beta, pi, B_zero, dirac): 
    if torch.norm(pi*dirac - pi) > 0.0001: 
        print('Bug')
        return False
    
    n = Y.shape[0]
    p = Y.shape[1]
    SrondS = torch.multiply(S,S)
    OplusM = O+M
    MmoinsXB = M-torch.mm(covariates, beta) 
    XB_zero = torch.mm(covariates, B_zero)
    tmp= n*p/2
    #tmp =  0 
    #pi = ksi_*dirac
    tmp -= n/2*torch.log(torch.det(Sigma))
    tmp += torch.sum(torch.multiply(1-pi,torch.multiply(Y, OplusM)  -torch.exp(OplusM+SrondS/2)-log_stirling(Y)*0)  +1/2*torch.log(SrondS))
    tmp += torch.sum(torch.multiply(pi,XB_zero))
    tmp -= torch.sum(torch.log(1+ torch.exp(XB_zero)))
    tmp -= 1/2*torch.trace(  
                            torch.mm(  
                                        torch.inverse(Sigma), 
                                        torch.diag(torch.sum(SrondS, dim = 0))+ torch.mm(MmoinsXB.T, MmoinsXB)
                                    )
                          )
    tmp -= torch.sum(torch.multiply(pi,trunc_log(pi)))
    
    tmp -= torch.sum(torch.multiply(1-pi,trunc_log(1-pi)))
    
    return tmp

def closed_Sigma(M,S,covariates,beta):
    '''
    closed form for Sigma with the first parametrisation centered in X\beta and variance Sigma 
    '''
    n,p = M.shape
    MmoinsXB = M-torch.mm(covariates,beta)
    return 1/(n)*(torch.mm(MmoinsXB.T,MmoinsXB) + torch.diag(torch.sum(torch.multiply(S,S), dim = 0)))

def closed_beta(X,M): # the X is the covariates. 
    '''
    closed form for beta with the first parametrisation above
    '''
    return torch.mm(torch.mm(torch.inverse(torch.mm(X.T,X)), X.T),M)

def closed_pi(O,M,S,dirac, covariates, B_zero): 
    '''
    closed form for pi with the parametrisation centered in Xbeta and variance Sigma
    '''
    A = torch.exp(O+M+torch.multiply(S,S)/2)
    pi_chap = torch.multiply(sigmoid(A+torch.mm(covariates, B_zero)), dirac)
    return pi_chap

# %%
show(model)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# max  1064378.8653837957

# %%
n_a = 0 
n_b = 50

sns.heatmap(model.Sigma[n_a:n_b, n_a:n_b])
# Out:
# <AxesSubplot:>

# %%
sns.heatmap((true_Sigma)[n_a:n_b,n_a:n_b])
# Out:
# <AxesSubplot:>

# %%
model_VEM = ZI_PLN(true_value = False, class_optimizer = torch.optim.Rprop)
model_VEM.fit_VEM(Y_sampled, O, covariates, tolerance = 0 ,Niter = 50,nb_each_iter= 5, lr = 0.01,  verbose = False)
# Out:
# 100%|██████████| 300/300 [00:00<00:00, 488.94it/s]
# nb iteration :  299
#  MSE with Sigma :  tensor(0.1366)
#  MSE with beta :  tensor(1.0211)
# MSE with B_zero 0.56144
#  MSE with Sigma :  tensor(0.1404)
#  MSE with beta :  tensor(0.9405)
# MSE with B_zero 0.5481
#  MSE with Sigma :  tensor(0.1638)
#  MSE with beta :  tensor(0.8579)
# MSE with B_zero 0.53479
#  MSE with Sigma :  tensor(0.2234)
#  MSE with beta :  tensor(0.7810)
# MSE with B_zero 0.52664
#  MSE with Sigma :  tensor(0.3372)
#  MSE with beta :  tensor(0.7145)
# MSE with B_zero 0.52152
#  MSE with Sigma :  tensor(0.5213)
#  MSE with beta :  tensor(0.6585)
# MSE with B_zero 0.52167
#  MSE with Sigma :  tensor(0.7981)
#  MSE with beta :  tensor(0.6120)
# MSE with B_zero 0.52437
#  MSE with Sigma :  tensor(1.1679)
#  MSE with beta :  tensor(0.5720)
# MSE with B_zero 0.53265
#  MSE with Sigma :  tensor(1.5833)
#  MSE with beta :  tensor(0.5383)
# MSE with B_zero 0.54521
#  MSE with Sigma :  tensor(2.0133)
#  MSE with beta :  tensor(0.5101)
# MSE with B_zero 0.5618
#  MSE with Sigma :  tensor(2.4127)
#  MSE with beta :  tensor(0.4857)
# MSE with B_zero 0.58218
#  MSE with Sigma :  tensor(2.7818)
#  MSE with beta :  tensor(0.4642)
# MSE with B_zero 0.6063
#  MSE with Sigma :  tensor(3.1008)
#  MSE with beta :  tensor(0.4447)
# MSE with B_zero 0.6303
#  MSE with Sigma :  tensor(3.3950)
#  MSE with beta :  tensor(0.4267)
# MSE with B_zero 0.65928
#  MSE with Sigma :  tensor(3.6618)
#  MSE with beta :  tensor(0.4108)
# MSE with B_zero 0.69325
#  MSE with Sigma :  tensor(3.8715)
#  MSE with beta :  tensor(0.3975)
# MSE with B_zero 0.71982
#  MSE with Sigma :  tensor(4.0443)
#  MSE with beta :  tensor(0.3863)
# MSE with B_zero 0.75038
#  MSE with Sigma :  tensor(4.1381)
#  MSE with beta :  tensor(0.3780)
# MSE with B_zero 0.77461
#  MSE with Sigma :  tensor(4.1798)
#  MSE with beta :  tensor(0.3709)
# MSE with B_zero 0.79698
#  MSE with Sigma :  tensor(4.1820)
#  MSE with beta :  tensor(0.3654)
# MSE with B_zero 0.81933
#  MSE with Sigma :  tensor(4.1513)
#  MSE with beta :  tensor(0.3613)
# MSE with B_zero 0.84365
#  MSE with Sigma :  tensor(4.1108)
#  MSE with beta :  tensor(0.3582)
# MSE with B_zero 0.86751
#  MSE with Sigma :  tensor(4.0496)
#  MSE with beta :  tensor(0.3564)
# MSE with B_zero 0.8907
#  MSE with Sigma :  tensor(3.9564)
#  MSE with beta :  tensor(0.3548)
# MSE with B_zero 0.91409
#  MSE with Sigma :  tensor(3.8119)
#  MSE with beta :  tensor(0.3534)
# MSE with B_zero 0.94202
#  MSE with Sigma :  tensor(3.6510)
#  MSE with beta :  tensor(0.3520)
# MSE with B_zero 0.96821
#  MSE with Sigma :  tensor(3.4711)
#  MSE with beta :  tensor(0.3508)
# MSE with B_zero 0.99192
#  MSE with Sigma :  tensor(3.3025)
#  MSE with beta :  tensor(0.3495)
# MSE with B_zero 1.01483
#  MSE with Sigma :  tensor(3.0995)
#  MSE with beta :  tensor(0.3489)
# MSE with B_zero 1.03979
#  MSE with Sigma :  tensor(2.9209)
#  MSE with beta :  tensor(0.3486)
# MSE with B_zero 1.0593
#  MSE with Sigma :  tensor(2.7693)
#  MSE with beta :  tensor(0.3482)
# MSE with B_zero 1.08014
#  MSE with Sigma :  tensor(2.6063)
#  MSE with beta :  tensor(0.3479)
# MSE with B_zero 1.09993
#  MSE with Sigma :  tensor(2.4560)
#  MSE with beta :  tensor(0.3479)
# MSE with B_zero 1.12512
#  MSE with Sigma :  tensor(2.3289)
#  MSE with beta :  tensor(0.3478)
# MSE with B_zero 1.14822
#  MSE with Sigma :  tensor(2.2035)
#  MSE with beta :  tensor(0.3479)
# MSE with B_zero 1.16909
#  MSE with Sigma :  tensor(2.0797)
#  MSE with beta :  tensor(0.3480)
# MSE with B_zero 1.19122
#  MSE with Sigma :  tensor(1.9655)
#  MSE with beta :  tensor(0.3481)
# MSE with B_zero 1.20573
#  MSE with Sigma :  tensor(1.8616)
#  MSE with beta :  tensor(0.3484)
# MSE with B_zero 1.21963
#  MSE with Sigma :  tensor(1.7596)
#  MSE with beta :  tensor(0.3486)
# MSE with B_zero 1.22853
#  MSE with Sigma :  tensor(1.6801)
#  MSE with beta :  tensor(0.3490)
# MSE with B_zero 1.23807
#  MSE with Sigma :  tensor(1.6115)
#  MSE with beta :  tensor(0.3494)
# MSE with B_zero 1.24627
#  MSE with Sigma :  tensor(1.5526)
#  MSE with beta :  tensor(0.3501)
# MSE with B_zero 1.25708
#  MSE with Sigma :  tensor(1.5041)
#  MSE with beta :  tensor(0.3509)
# MSE with B_zero 1.26855
#  MSE with Sigma :  tensor(1.4554)
#  MSE with beta :  tensor(0.3520)
# MSE with B_zero 1.27657
#  MSE with Sigma :  tensor(1.4140)
#  MSE with beta :  tensor(0.3526)
# MSE with B_zero 1.28911
#  MSE with Sigma :  tensor(1.3888)
#  MSE with beta :  tensor(0.3537)
# MSE with B_zero 1.29147
#  MSE with Sigma :  tensor(1.3726)
#  MSE with beta :  tensor(0.3547)
# MSE with B_zero 1.29839
#  MSE with Sigma :  tensor(1.3554)
#  MSE with beta :  tensor(0.3557)
# MSE with B_zero 1.3104
#  MSE with Sigma :  tensor(1.3438)
#  MSE with beta :  tensor(0.3567)
# MSE with B_zero 1.31879
#  MSE with Sigma :  tensor(1.3405)
#  MSE with beta :  tensor(0.3580)
# MSE with B_zero 1.32629

# %%
show(model_VEM)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# max  12109345128966.473

# %%
torch.mean((model.beta-true_beta)**2)
# Out:
# tensor(0.0096)

# %%
true_beta
# Out:
# tensor([[ 0.5407,  0.9368, -1.7223, -0.6983, -0.2822, -0.0617,  1.2470,  0.0215,
#          -0.4011, -0.1015, -1.1471,  0.2039, -1.5762, -0.3079, -0.9071,  0.7639,
#           0.4274,  0.1167, -1.1111,  0.4674],
#         [ 0.6230, -2.6717,  0.2744, -1.9610, -0.5957, -0.4857, -0.5909,  1.1391,
#           0.3542,  2.7316,  0.9745,  0.0454,  0.7718, -0.2056, -1.3896, -1.6107,
#          -0.5210,  0.0539,  0.3225, -0.2288]])

# %%
d = 2 # nb of cavariates
n = 200; p = 200

# %%
#torch.manual_seed(0)
#true_Sigma = torch.from_numpy(toeplitz(0.6**np.arange(p)))
true_Sigma = torch.from_numpy(build_block_Sigma(p,15)).to(device)
true_C = torch.cholesky(true_Sigma)
true_beta = torch.randn(d, p).to(device)

covariates = torch.randn((n,d))/1.2
O = 0+torch.zeros((n,p))
true_B_zero = torch.randn((d,p)).to(device)
#sample_model = sample_PLN(ZI = True)
Y_sampled, Z_sampled, ksi  = sample_PLN(true_Sigma.to(torch.device('cpu')),true_beta.to(torch.device('cpu')), O, covariates, true_B_zero, ZI = True)
try : 
    ksi = torch.from_numpy(ksi)
except : 
    pass

Y_sampled = torch.from_numpy(Y_sampled)
data = [Y_sampled.double(), O, covariates]

# %%
torch.max(Y_sampled)
# Out:
# tensor(4968)

# %%
def log_p_ksi(B_zer,ksi): 
    XB_zer = torch.mm(covariates, B_zer)
    return torch.sum(torch.multiply(ksi,XB_zer)- torch.log(1+ torch.exp(XB_zer)))

# B_init = torch.randn((d,p))

# %%
def fit(ksi): 
    B_zer = torch.randn((d,p), requires_grad = True)
    optim = torch.optim.Rprop([B_zer], lr = 0.1)
    for i in range( 100): 
        loss = - log_p_ksi(B_zer,ksi)
        loss.backward()
        optim.step()
        optim.zero_grad()
        #print('MSE :', MSE(B_zer-true_B_zero))
    return B_zer  
# B_zer = fit(ksi)

# %%
def batch_log_P_WgivenY(Y_b, covariates_b, O_b, W, C, beta): 
    length = len(W.shape)
    if length == 2 : 
        CW = torch.matmul(C.unsqueeze(0),W.unsqueeze(2)).squeeze()
    elif length == 3 : 
        CW = torch.matmul(C.unsqueeze(0).unsqueeze(1), W.unsqueeze(3)).squeeze()
    A_b = O_b + CW + covariates_b@beta
    return -1/2*torch.norm(W, dim = -1)**2 + torch.sum(-torch.exp(A_b)   + A_b*Y_b - log_stirling(Y_b) , axis = -1)
